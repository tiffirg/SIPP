# %% [markdown]
# # Safe Interval Path Planning On a Grid :: SIPP Algorithm (based on A* with idea of safe intervals)

# %% [markdown]
# In this project, we will consider the problem of finding the fastest safe path on a graph with a special structure, widely used in robotics and computer games — a grid. The grid consists of both free and blocked cells, and an agent can move from one free cell to another. Our grid will also have some obstacles and they will be moving. Algortihm needs to find a route that does not intrfere with obstacles at any point in our discrete time

# %%
import random
import traceback
from heapq import heappop, heappush
from pathlib import Path
from textwrap import dedent
from typing import Callable, Dict, Iterable, List, Optional, Tuple, Type, Union

import matplotlib.pyplot as plt
import numpy as np
import numpy.typing as npt
from PIL import Image, ImageDraw

# from tests.Map import Map

from bs4 import BeautifulSoup
import numpy as np
import bisect
import lxml


# %matplotlib inline

# %%
INF = 100000000


class Interval:
    def __init__(self, is_safe=False, start_time=0, end_time=0):
        self.is_safe = is_safe
        self.start_time = start_time
        self.end_time = end_time

    def empty(self):
        return not self.is_safe and not self.start_time and not self.end_time

    def __eq__(self, other):
        return self.start_time == other.start_time and self.end_time == other.end_time

    def __str__(self):
        return "{" + str(self.is_safe) + ", " + str(self.start_time) + ", " + str(self.end_time) + "}"


class PathComponent:
    def __init__(self, x=0, y=0, time=0):
        self.x = x
        self.y = y
        self.time = time

    def __str__(self):
        return f"({self.x}, {self.y}, {self.time})"


class Obstacle:
    def __init__(self):
        self.path = []


class Map:
    def __init__(self, map_path: str):
        self.cost = 1

        with open(map_path, 'r') as xml_file:
            soup = BeautifulSoup(xml_file, "lxml")
        if soup.map is None:
            raise ValueError("ERROR: nothing in map tag")
        self.soup = soup.map
        self.map = None
        self.dynamic_obstacles = []
        self.width = 0
        self.height = 0
        self.start_i, self.start_j = 0, 0
        self.goal_i, self.goal_j = 0, 0

        self.allow_diagonal = True
        self.cut_corners = True
        self.allow_squeeze = True

        self.__get_map()

    def __get_map(self):
        data_ptrs = [int(self.soup.width.text), int(self.soup.height.text), int(self.soup.startx.text),
                     int(self.soup.starty.text), int(self.soup.finishx.text), int(self.soup.finishy.text)]
        

        for data_ptr in data_ptrs:
            if data_ptr is None or data_ptr <= 0:
                raise ValueError("ERROR: invalid value of the width, height, start of goal position")

        for i in range(2, len(data_ptrs)):
            data_ptrs[i] -= 1

        self.width, self.height, self.start_i, self.start_j, self.goal_i, self.goal_j = data_ptrs

        self.map = [[[] for j in range(self.width)] for i in range(self.height)]
        if self.soup.grid is None:
            raise ValueError("ERROR: nothing in grid tag")
        grid = self.soup.grid
        for i, row in enumerate(grid.find_all("row")):
            for j, el in enumerate(row.get_text().split()):
                el = int(el)
                if bool(el):
                    interval = Interval(is_safe=False, start_time=0, end_time=INF)
                    self.map[i][j].append(interval)

        dynamic_obstacles = self.soup.dynamicobstacles
        for obstacle in dynamic_obstacles.find_all("obstacle"):
            self.dynamic_obstacles.append(Obstacle())
            for point in obstacle.find_all("point"):
                x, y, time = int(point["x"]), int(point["y"]), int(point["time"])
                if self.dynamic_obstacles[-1].path:
                    prev_point = self.dynamic_obstacles[-1].path[-1]
                    distance = self.get_distance(x - 1, y - 1, prev_point[0], prev_point[1])

                    if ((distance == 0 and (time * self.cost - prev_point[2]) <= 0) or
                            (distance != 0 and distance != (time * self.cost - prev_point[2]))):
                        raise ValueError("ERROR: invalid path representation")

                self.dynamic_obstacles[-1].path.append((x - 1, y - 1, time * self.cost))

    def get_successors(self, node):
        successors = []
        for i in range(max(0, node.i - 1), min(node.i + 2, self.get_height())):
            for j in range(max(0, node.j - 1), min(node.j + 2, self.get_width())):
                if self.is_traversable(i, j):
                    cost = self.cost
                    if (i + j) % 2 == (node.i + node.j) % 2:
                        if not self.check_diagonal_successor(node, i, j):
                            continue
                        cost = np.sqrt(2)

                    min_time = node.g + cost / 2
                    if self.map[i][j]:
                        max_time = self.map[node.i][node.j][node.interval].end_time
                    else:
                        max_time = INF

                    if min_time >= max_time:
                        continue

                    self.set_intervals(i, j)

                    interval = (self.get_safe_interval_id(i, j, min_time))
                    successors.append((i, j, cost, interval))
                    # while interval < len(self.map[i][j]) and self.map[i][j][interval].start_time < max_time:
                    #     successor = cells2nodes[(i, j, interval)]
                    #     new_g = max(
                    #         node.g + cost,
                    #         self.map[i][j][interval].startTime + cost / 2
                    #     )
                    #
                    #     if successor is None:
                    #         successor = Node(
                    #             i,
                    #             j,
                    #             interval,
                    #             new_g,
                    #             getHeuristic(i, j, map),
                    #             node
                    #         )
                    #         cells2nodes[(i, j, interval)] = successor
                    #         OPEN.append(successor)
                    #     successors.append((successor, new_g))
                    #
                    # interval += 1

        return successors

    def check_diagonal_successor(self, node, i, j):
        if not self.allow_diagonal or (node.i == i and node.j == j):
            return False

        near_cell1 = self.is_traversable(node.i, j)
        near_cell2 = self.is_traversable(i, node.j)

        return (near_cell1 and near_cell2) or \
               (self.cut_corners and (near_cell1 or near_cell2)) or \
               (self.allow_squeeze and not near_cell1 and not near_cell2)

    def get_distance(self, i1, j1, i2, j2):
        return (abs(i2 - i1) + abs(j2 - j1)) * self.cost

    def get_cost(self):
        return self.cost

    def is_traversable(self, i, j):
        print(f"is_traversable {i} {j}")
        return not self.map[i][j] or self.map[i][j][0].is_safe

    def get_width(self):
        return self.width

    def get_height(self):
        return self.height

    def get_start_cell(self):
        return self.start_i, self.start_j

    def get_goal_cell(self):
        return self.goal_i, self.goal_j

    def point_on_segment(self, point, p1, p2) -> bool:
        point, p1, p2 = np.array(point), np.array(p1), np.array(p2)
        diff1, diff2 = p1 - point, p2 - point
        return diff1[0] * diff2[1] - diff1[1] * diff2[0] == 0 and diff1[0] * diff1[1] + diff2[0] * diff2[1] >= 0

    def set_intervals(self, i, j):
        if self.map[i][j]:
            return

        collision_intervals: list[Interval] = []

        for obstacle in self.dynamic_obstacles:
            path = obstacle.path
            print(path[0])
            for point_i in range(1, len(path)):
                if not self.point_on_segment((j, i), [path[point_i - 1][0], path[point_i - 1][1]],
                                             [path[point_i][0], path[point_i][1]]):
                    continue

                collision_intervals.append(
                    Interval(
                        False,
                        path[point_i - 1][2] + self.get_distance(i, j, path[point_i - 1][1],
                                                                   path[point_i - 1][0]) - self.cost / 2,
                        path[point_i - 1][2] + self.get_distance(i, j, path[point_i - 1][1],
                                                                   path[point_i - 1][0]) + self.cost / 2
                    )
                )

                if self.get_distance(path[point_i - 1][1], path[point_i - 1][0], path[point_i][1], path[point_i][0]) == 0:
                    collision_intervals[-1].end_time = path[point_i][2] + self.cost / 2

        collision_intervals.sort(key=lambda x: x.start_time)

        if not collision_intervals:
            self.map[i][j].append(Interval(True, 0, INF))
            return

        for interval in collision_intervals:
            if not self.map[i][j] or interval.start_time > self.map[i][j][-1].end_time:
                self.map[i][j].append(interval)

            self.map[i][j][-1].end_time = max(self.map[i][j][-1].end_time, interval.end_time)

        if self.map[i][j][0].start_time > 0:
            self.map[i][j].append(Interval(True, self.map[i][j][-1].end_time, INF))
            for interval in range(len(self.map[i][j]) - 2, -1, -1):
                self.map[i][j][interval].is_safe = True
                self.map[i][j][interval].end_tme = self.map[i][j][interval].start_time
                self.map[i][j][interval].start_time = 0 if interval == 0 else self.map[i][j][interval - 1].end_time
        else:
            for interval in range(len(self.map[i][j])):
                self.map[i][j][interval].is_safe = True
                self.map[i][j][interval].start_time = self.map[i][j][interval].end_time

                if interval + 1 == len(self.map[i][j]):
                    self.map[i][j][interval].end_time = INF
                    continue

                self.map[i][j][interval].end = self.map[i][j][interval + 1].start_time

    def get_safe_interval_id(self, i, j, time):
        def compare(time, interval):
            return time < interval.end_time

        return bisect.bisect_right(self.map[i][j], time, key=lambda x: compare(time, x)) - 1

    def get_interval_start(self, i, j, interval):
        return self.map[i][j][interval].start_time

    def get_interval_end(self, i, j, interval):
        return self.map[i][j][interval].end_time

# %%
class Node:
    """
    Represents a search node.

    Attributes
    ----------
    i : int
        Row coordinate of the corresponding grid element.
    j : int
        Column coordinate of the corresponding grid element.
    g : float | int
        g-value of the node.
    h : float | int
        h-value of the node
    f : float | int
        f-value of the node
    parent : Node
        Pointer to the parent node.
    """

    def __init__(
        self,
        i: int,
        j: int,
        interval: int,
        g: Union[float, int] = 0,
        h: Union[float, int] = 0,
        f: Optional[Union[float, int]] = None,
        parent: "Node" = None,
    ):
        """
        Initializes a search node.

        Parameters
        ----------
        i : int
            Row coordinate of the corresponding grid element.
        j : int
            Column coordinate of the corresponding grid element.
        g : float | int
            g-value of the node.
        h : float | int
            h-value of the node (always 0 for Dijkstra).
        f : float | int
            f-value of the node (always equal to g-value for Dijkstra).
        parent : Node
            Pointer to the parent node.
        """
        self.i = i
        self.j = j
        self.g = g
        self.h = h
        self.interval = interval
        if f is None:
            self.f = self.g + h
        else:
            self.f = f
        self.parent = parent

    def __eq__(self, other):
        """
        Checks if two search nodes are the same, which is needed to detect duplicates in the search tree.
        """
        return self.i == other.i and self.j == other.j

    def __hash__(self):
        """
        Makes the Node object hashable, allowing it to be used in sets/dictionaries.
        """
        return hash((self.i, self.j))

    def __lt__(self, other):
        """
        Compares the keys (i.e., the f-values) of two nodes, needed for sorting/extracting the best element from OPEN.
        """
        if self.f == other.f:
            return self.g > other.g
        return self.f < other.f

# %%
test_map = Map("../data/den101d_200_1.xml")

# %% [markdown]
# Computes the cost of a transition from cell `(i1, j1)` to cell `(i2, j2)`. In the case of a 4-connected grid, the cost is always equal to 1. Consequently, the cost of each path is an integer.
#
# However, please note that if the grid's connectivity exceeds 4, the cost of a transition may vary and may become fractional or even arbitrary (e.g., $\sqrt{2}$ for diagonal moves).
#
# Recall that in this lab, we assume a 4-connected grid, meaning that only cardinal moves (up, down, left, right) are allowed, and as a result, all costs are integers.

# %% [markdown]
# ## Search Node
#
# A Search node is a fundamental concept in heuristic search algorithms. It encapsulates data about the state of the problem (e.g., the position of a robot or agent on a grid) and the information needed to construct a search tree, including g-values, h-values, f-values, and a backpointer to its predecessor.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Implementing the Search Tree (i.e., OPEN and CLOSED)
# An efficient implementation of the search tree (`OPEN` and `CLOSED`) is crucial for any search algorithm. You should utilize the efficient search tree implementation you developed in the previous lab.

# %%
class SearchTreePQD:
    """
    SearchTree using a priority queue for OPEN and a dictionary for CLOSED.
    """

    def __init__(self):
        self._open = []  # Priority queue for nodes in OPEN
        self._closed = {}  # Dictionary for nodes in CLOSED (expanded nodes)
        self._enc_open_duplicates = 0  # Number of duplicates encountered in OPEN

    def __len__(self) -> int:
        """
        Returns the size of the search tree. Useful for assessing the memory
        footprint of the algorithm, especially at the final iteration.
        """
        return len(self._open) + len(self._closed)

    def open_is_empty(self) -> bool:
        """
        Checks if OPEN is empty.
        If true, the main search loop should be interrupted.
        """
        return len(self._open) == 0

    def add_to_open(self, item: Node):
        """
        Adds a node to the search tree, specifically to OPEN. This node is either
        entirely new or a duplicate of an existing node in OPEN.
        This implementation detects duplicates lazily; thus, nodes are added to
        OPEN without initial duplicate checks.
        """
        heappush(self._open, item)

    def get_best_node_from_open(self) -> Optional[Node]:
        """
        Retrieves the best node from OPEN, defined by the minimum key.
        This node will then be expanded in the main search loop.

        Duplicates are managed here. If a node has been expanded previously
        (and is in CLOSED), it's skipped and the next best node is considered.

        Returns None if OPEN is empty.
        """
        while not self.open_is_empty():
            item = heappop(self._open)
            if item not in self._closed:
                return item
            else:
                self._enc_open_duplicates += 1
        return None

    def add_to_closed(self, item: Node):
        """
        Adds a node to the CLOSED dictionary.
        """
        self._closed[item] = item

    def was_expanded(self, item: Node) -> bool:
        """
        Checks if a node has been previously expanded.
        """
        return item in self._closed.keys()

    @property
    def opened(self):
        return self._open

    @property
    def expanded(self):
        return self._closed.keys()

    @property
    def number_of_open_dublicates(self):
        return self._enc_open_duplicates

# %% [markdown]
# ## Validating the Results

# %% [markdown]
# ## A* Algorithm Without Reexpansions

# %% [markdown]
# The primary component of the `A*` algorithm is the heuristic function.
#
# Ideally, this function should be admissible (it never overestimates the true cost to the goal) and consistent (satisfies the triangle inequality). The Manhattan distance serves as an admissible and consistent heuristic for 4-connected grids. Therefore, if we integrate it into the `Dijkstra` search loop from the previous lab, we'll obtain the `A*` algorithm.
#
# Let's proceed!

# %% [markdown]
# The input for the `A*` algorithm implementation is the same as for `Dijkstra`:
#
# The input is:
# - map representation
# - start/goal cells
# - heuristic function $^*$
# - a reference to the implementation of the SearchTree
#
# The output is:
# - path found flag (`true` or `false`)
# - last node of the path (so one can unwind it using the parent-pointers and get the full path)
# - the number of steps (iterations of the main loop)
# - the number of nodes that compose the search tree at the final iteration of the algorithm (=the size of the resultant search tree)
# - OPEN and CLOSED (as iterable collections of nodes) for further visualization purposes
#
#
# PS: You might also want to display, at the final iteration, the number of OPEN duplicates encountered during the search, as shown below:
#
# ```print("During the search, the following number of OPEN dublicates was encountered: ", ast.number_of_open_duplicates) ```

# %%
def astar(
    task_map: Map,
    start_i: int,
    start_j: int,
    goal_i: int,
    goal_j: int,
    heuristic_func: Callable,
    search_tree: Type[SearchTreePQD],
) -> Tuple[bool, Optional[Node], int, int, Optional[Iterable[Node]], Optional[Iterable[Node]]]:
    """
    Implements the A* search algorithm.

    Parameters
    ----------
    task_map : Map
        The grid or map being searched.
    start_i, start_j : int, int
        Starting coordinates.
    goal_i, goal_j : int, int
        Goal coordinates.
    heuristic_func : Callable
        Heuristic function for estimating the distance from a node to the goal.
    search_tree : Type[SearchTreePQD]
        The search tree to use.

    Returns
    -------
    Tuple[bool, Optional[Node], int, int, Optional[Iterable[Node]], Optional[Iterable[Node]]]
        Tuple containing:
        - A boolean indicating if a path was found.
        - The last node in the found path or None.
        - Number of algorithm iterations.
        - Size of the resultant search tree.
        - OPEN set nodes for visualization or None.
        - CLOSED set nodes.
    """
    ast = search_tree()
    steps = 0

    start_node = Node(start_i, start_j, interval = 0, g=0, h=heuristic_func(start_i, start_j, goal_i, goal_j))
    ast.add_to_open(start_node)

    while not ast.open_is_empty():
        current = ast.get_best_node_from_open()

        steps += 1

        if current is None:
            break

        if current.i == goal_i and current.j == goal_j:  # is goal
            return True, current, steps, len(ast), ast.opened, ast.expanded
        
        ast.add_to_closed(current)

        print(f"Current node {current.i}, {current.j}, interval {current.interval}")

        for i, j, cost, interval  in task_map.get_successors(current):
            print(i,j, interval)
            new = Node(i, j, interval)
            if not ast.was_expanded(new):

                new.parent = current

                new.h = heuristic_func(i, j, goal_i, goal_j)
                new.g = current.g + task_map.get_distance(current.i, current.j, i, j)
                new.f = new.g  + new.h

                ast.add_to_open(new)

    return False, None, steps, len(ast), None, ast.expanded

# %%
print(len(test_map.map), len(test_map.map[0]))
# Out:
# 41 73

# %%
_, current, _, _, _, _ = astar(test_map, test_map.start_j, test_map.start_i, test_map.goal_j, test_map.goal_i, test_map.get_distance, SearchTreePQD)
# Out:
# Current node 33, 9, interval 0
# is_traversable 32 8
# is_traversable 33 8
# is_traversable 32 9
# is_traversable 32 9
# is_traversable 32 10
# is_traversable 33 10
# is_traversable 32 9
# is_traversable 33 8
# is_traversable 33 9
# is_traversable 33 10
# is_traversable 34 8
# is_traversable 33 8
# is_traversable 34 9
# is_traversable 34 9
# is_traversable 34 10
# is_traversable 33 10
# is_traversable 34 9
# 32 8 -1
# 32 9 -1
# 32 10 -1
# 33 8 -1
# 33 10 -1
# 34 8 -1
# 34 9 -1
# 34 10 -1
# Current node 32, 10, interval -1
# is_traversable 31 9
# is_traversable 32 9
# is_traversable 31 10
# is_traversable 31 10
# is_traversable 31 11
# is_traversable 32 11
# is_traversable 31 10
# is_traversable 32 9
# is_traversable 32 10
# is_traversable 32 11
# is_traversable 33 9
# is_traversable 32 9
# is_traversable 33 10
# is_traversable 33 10
# is_traversable 33 11
# is_traversable 32 11
# is_traversable 33 10
# 31 9 36
# 31 10 36
# 31 11 37
# 32 9 37
# 32 11 33
# 33 9 35
# 33 10 27
# 33 11 30
# Current node 31, 11, interval 37
# is_traversable 30 10
# is_traversable 31 10
# is_traversable 30 11
# is_traversable 30 11
# is_traversable 30 12
# is_traversable 31 12
# is_traversable 30 11
# is_traversable 31 10
# is_traversable 31 11
# is_traversable 31 12
# is_traversable 32 10
# is_traversable 31 10
# is_traversable 32 11
# is_traversable 32 11
# is_traversable 32 12
# is_traversable 31 12
# is_traversable 32 11
# 30 10 26
# 30 11 37
# 30 12 31
# 31 10 36
# 31 12 53
# 32 10 35
# 32 11 33
# 32 12 37
# Current node 30, 12, interval 31
# is_traversable 29 11
# is_traversable 30 11
# is_traversable 29 12
# is_traversable 29 12
# is_traversable 29 13
# is_traversable 30 13
# is_traversable 29 12
# is_traversable 30 11
# is_traversable 30 12
# is_traversable 30 13
# is_traversable 31 11
# is_traversable 30 11
# is_traversable 31 12
# is_traversable 31 12
# is_traversable 31 13
# is_traversable 30 13
# is_traversable 31 12
# 29 11 29
# 29 12 38
# 29 13 32
# 30 11 37
# 30 13 35
# 31 11 37
# 31 12 53
# 31 13 39
# Current node 29, 13, interval 32
# is_traversable 28 12
# is_traversable 29 12
# is_traversable 28 13
# is_traversable 28 13
# is_traversable 28 14
# is_traversable 29 14
# is_traversable 28 13
# is_traversable 29 12
# is_traversable 29 13
# is_traversable 29 14
# is_traversable 30 12
# is_traversable 29 12
# is_traversable 30 13
# is_traversable 30 13
# is_traversable 30 14
# is_traversable 29 14
# is_traversable 30 13
# 28 12 27
# 28 13 33
# 28 14 26
# 29 12 38
# 29 14 41
# 30 12 31
# 30 13 35
# 30 14 38
# Current node 28, 14, interval 26
# is_traversable 27 13
# is_traversable 28 13
# is_traversable 27 14
# is_traversable 27 14
# is_traversable 27 15
# is_traversable 28 15
# is_traversable 27 14
# is_traversable 28 13
# is_traversable 28 14
# is_traversable 28 15
# is_traversable 29 13
# is_traversable 28 13
# is_traversable 29 14
# is_traversable 29 14
# is_traversable 29 15
# is_traversable 28 15
# is_traversable 29 14
# 27 13 33
# 27 14 33
# 27 15 39
# 28 13 33
# 28 15 39
# 29 13 32
# 29 14 41
# 29 15 44
# Current node 27, 15, interval 39
# is_traversable 26 14
# is_traversable 27 14
# is_traversable 26 15
# is_traversable 26 15
# is_traversable 26 16
# is_traversable 27 16
# is_traversable 26 15
# is_traversable 27 14
# is_traversable 27 15
# is_traversable 27 16
# is_traversable 28 14
# is_traversable 27 14
# is_traversable 28 15
# is_traversable 28 15
# is_traversable 28 16
# is_traversable 27 16
# is_traversable 28 15
# 26 14 45
# 26 15 55
# 26 16 64
# 27 14 33
# 27 16 37
# 28 14 26
# 28 15 39
# 28 16 38
# Current node 26, 16, interval 64
# is_traversable 25 15
# is_traversable 25 16
# is_traversable 25 17
# is_traversable 26 15
# is_traversable 26 16
# is_traversable 26 17
# is_traversable 27 15
# is_traversable 26 15
# is_traversable 27 16
# is_traversable 27 16
# is_traversable 27 17
# is_traversable 26 17
# is_traversable 27 16
# 26 15 55
# 26 17 70
# 27 15 39
# 27 16 37
# 27 17 48
# Current node 26, 17, interval 70
# is_traversable 25 16
# is_traversable 25 17
# is_traversable 25 18
# is_traversable 26 18
# is_traversable 25 17
# is_traversable 26 16
# is_traversable 26 17
# is_traversable 26 18
# is_traversable 27 16
# is_traversable 26 16
# is_traversable 27 17
# is_traversable 27 17
# is_traversable 27 18
# is_traversable 26 18
# is_traversable 27 17
# 25 18 65
# 26 16 64
# 26 18 63
# 27 16 37
# 27 17 48
# 27 18 40
# Current node 25, 18, interval 65
# is_traversable 24 17
# is_traversable 24 18
# is_traversable 24 19
# is_traversable 25 19
# is_traversable 24 18
# is_traversable 25 17
# is_traversable 25 18
# is_traversable 25 19
# is_traversable 26 17
# is_traversable 25 17
# is_traversable 26 18
# is_traversable 26 18
# is_traversable 26 19
# is_traversable 25 19
# is_traversable 26 18
# 24 18 58
# 24 19 69
# 25 19 69
# 26 17 70
# 26 18 63
# 26 19 59
# Current node 24, 19, interval 69
# is_traversable 23 18
# is_traversable 24 18
# is_traversable 23 19
# is_traversable 23 19
# is_traversable 23 20
# is_traversable 24 20
# is_traversable 23 19
# is_traversable 24 18
# is_traversable 24 19
# is_traversable 24 20
# is_traversable 25 18
# is_traversable 24 18
# is_traversable 25 19
# is_traversable 25 19
# is_traversable 25 20
# is_traversable 24 20
# is_traversable 25 19
# 23 18 69
# 23 19 62
# 23 20 49
# 24 18 58
# 24 20 36
# 25 18 65
# 25 19 69
# 25 20 45
# Current node 23, 20, interval 49
# is_traversable 22 19
# is_traversable 23 19
# is_traversable 22 20
# is_traversable 22 20
# is_traversable 22 21
# is_traversable 23 21
# is_traversable 22 20
# is_traversable 23 19
# is_traversable 23 20
# is_traversable 23 21
# is_traversable 24 19
# is_traversable 23 19
# is_traversable 24 20
# is_traversable 24 20
# is_traversable 24 21
# is_traversable 23 21
# is_traversable 24 20
# 22 19 91
# 22 20 49
# 22 21 43
# 23 19 62
# 23 21 36
# 24 19 69
# 24 20 36
# 24 21 42
# Current node 22, 21, interval 43
# is_traversable 21 20
# is_traversable 22 20
# is_traversable 21 21
# is_traversable 21 21
# is_traversable 21 22
# is_traversable 22 22
# is_traversable 21 21
# is_traversable 22 20
# is_traversable 22 21
# is_traversable 22 22
# is_traversable 23 20
# is_traversable 22 20
# is_traversable 23 21
# is_traversable 23 21
# is_traversable 23 22
# is_traversable 22 22
# is_traversable 23 21
# 21 20 46
# 21 21 29
# 21 22 41
# 22 20 49
# 22 22 52
# 23 20 49
# 23 21 36
# 23 22 32
# Current node 21, 22, interval 41
# is_traversable 20 21
# is_traversable 21 21
# is_traversable 20 22
# is_traversable 20 22
# is_traversable 20 23
# is_traversable 21 23
# is_traversable 20 22
# is_traversable 21 21
# is_traversable 21 22
# is_traversable 21 23
# is_traversable 22 21
# is_traversable 21 21
# is_traversable 22 22
# is_traversable 22 22
# is_traversable 22 23
# is_traversable 21 23
# is_traversable 22 22
# 20 21 49
# 20 22 46
# 20 23 58
# 21 21 29
# 21 23 46
# 22 21 43
# 22 22 52
# 22 23 69
# Current node 20, 23, interval 58
# is_traversable 19 22
# is_traversable 20 22
# is_traversable 19 23
# is_traversable 19 23
# is_traversable 19 24
# is_traversable 20 24
# is_traversable 19 23
# is_traversable 20 22
# is_traversable 20 23
# is_traversable 20 24
# is_traversable 21 22
# is_traversable 20 22
# is_traversable 21 23
# is_traversable 21 23
# is_traversable 21 24
# is_traversable 20 24
# is_traversable 21 23
# 19 22 48
# 19 23 52
# 19 24 88
# 20 22 46
# 20 24 71
# 21 22 41
# 21 23 46
# 21 24 63
# Current node 19, 24, interval 88
# is_traversable 18 23
# is_traversable 19 23
# is_traversable 18 24
# is_traversable 18 24
# is_traversable 18 25
# is_traversable 19 25
# is_traversable 18 24
# is_traversable 19 23
# is_traversable 19 24
# is_traversable 19 25
# is_traversable 20 23
# is_traversable 19 23
# is_traversable 20 24
# is_traversable 20 24
# is_traversable 20 25
# is_traversable 19 25
# is_traversable 20 24
# 18 23 51
# 18 24 77
# 18 25 51
# 19 23 52
# 19 25 54
# 20 23 58
# 20 24 71
# 20 25 54
# Current node 18, 25, interval 51
# is_traversable 17 24
# is_traversable 17 25
# is_traversable 17 26
# is_traversable 18 24
# is_traversable 18 25
# is_traversable 18 26
# is_traversable 19 24
# is_traversable 18 24
# is_traversable 19 25
# is_traversable 19 25
# is_traversable 19 26
# is_traversable 18 26
# is_traversable 19 25
# 18 24 77
# 18 26 61
# 19 24 88
# 19 25 54
# 19 26 56
# Current node 18, 26, interval 61
# is_traversable 17 25
# is_traversable 17 26
# is_traversable 17 27
# is_traversable 18 27
# is_traversable 17 26
# is_traversable 18 25
# is_traversable 18 26
# is_traversable 18 27
# is_traversable 19 25
# is_traversable 18 25
# is_traversable 19 26
# is_traversable 19 26
# is_traversable 19 27
# is_traversable 18 27
# is_traversable 19 26
# 17 27 96
# 18 25 51
# 18 27 56
# 19 25 54
# 19 26 56
# 19 27 56
# Current node 17, 27, interval 96
# is_traversable 16 26
# is_traversable 16 27
# is_traversable 16 28
# is_traversable 17 28
# is_traversable 16 27
# is_traversable 17 26
# is_traversable 17 27
# is_traversable 17 28
# is_traversable 18 26
# is_traversable 17 26
# is_traversable 18 27
# is_traversable 18 27
# is_traversable 18 28
# is_traversable 17 28
# is_traversable 18 27
# 16 27 71
# 16 28 90
# 17 28 97
# 18 26 61
# 18 27 56
# 18 28 51
# Current node 16, 28, interval 90
# is_traversable 15 27
# is_traversable 16 27
# is_traversable 15 28
# is_traversable 15 28
# is_traversable 15 29
# is_traversable 16 27
# is_traversable 16 28
# is_traversable 16 29
# is_traversable 17 27
# is_traversable 16 27
# is_traversable 17 28
# is_traversable 17 28
# is_traversable 17 29
# 15 27 74
# 15 28 88
# 16 27 71
# 17 27 96
# 17 28 97
# Current node 15, 28, interval 88
# is_traversable 14 27
# is_traversable 15 27
# is_traversable 14 28
# is_traversable 14 28
# is_traversable 14 29
# is_traversable 15 29
# is_traversable 14 28
# is_traversable 15 27
# is_traversable 15 28
# is_traversable 15 29
# is_traversable 16 27
# is_traversable 15 27
# is_traversable 16 28
# is_traversable 16 28
# is_traversable 16 29
# 14 27 38
# 14 28 47
# 14 29 71
# 15 27 74
# 16 27 71
# 16 28 90
# Current node 14, 29, interval 71
# is_traversable 13 28
# is_traversable 14 28
# is_traversable 13 29
# is_traversable 13 29
# is_traversable 13 30
# is_traversable 14 30
# is_traversable 13 29
# is_traversable 14 28
# is_traversable 14 29
# is_traversable 14 30
# is_traversable 15 28
# is_traversable 14 28
# is_traversable 15 29
# is_traversable 15 29
# is_traversable 15 30
# 13 28 26
# 13 29 40
# 13 30 22
# 14 28 47
# 14 30 57
# 15 28 88
# Current node 13, 30, interval 22
# is_traversable 12 29
# is_traversable 13 29
# is_traversable 12 30
# is_traversable 12 30
# is_traversable 12 31
# is_traversable 13 31
# is_traversable 12 30
# is_traversable 13 29
# is_traversable 13 30
# is_traversable 13 31
# is_traversable 14 29
# is_traversable 13 29
# is_traversable 14 30
# is_traversable 14 30
# is_traversable 14 31
# is_traversable 13 31
# is_traversable 14 30
# 12 29 55
# 12 30 43
# 12 31 60
# 13 29 40
# 13 31 37
# 14 29 71
# 14 30 57
# 14 31 50
# Current node 12, 31, interval 60
# is_traversable 11 30
# is_traversable 12 30
# is_traversable 11 31
# is_traversable 11 31
# is_traversable 11 32
# is_traversable 12 32
# is_traversable 11 31
# is_traversable 12 30
# is_traversable 12 31
# is_traversable 12 32
# is_traversable 13 30
# is_traversable 12 30
# is_traversable 13 31
# is_traversable 13 31
# is_traversable 13 32
# is_traversable 12 32
# is_traversable 13 31
# 11 30 36
# 11 31 42
# 11 32 40
# 12 30 43
# 12 32 51
# 13 30 22
# 13 31 37
# 13 32 28
# Current node 11, 32, interval 40
# is_traversable 10 31
# is_traversable 10 32
# is_traversable 10 33
# is_traversable 11 31
# is_traversable 11 32
# is_traversable 11 33
# is_traversable 12 31
# is_traversable 11 31
# is_traversable 12 32
# is_traversable 12 32
# is_traversable 12 33
# is_traversable 11 33
# is_traversable 12 32
# 11 31 42
# 11 33 64
# 12 31 60
# 12 32 51
# 12 33 63
# Current node 11, 33, interval 64
# is_traversable 10 32
# is_traversable 10 33
# is_traversable 10 34
# is_traversable 11 32
# is_traversable 11 33
# is_traversable 11 34
# is_traversable 12 32
# is_traversable 11 32
# is_traversable 12 33
# is_traversable 12 33
# is_traversable 12 34
# is_traversable 11 34
# is_traversable 12 33
# 11 32 40
# 11 34 58
# 12 32 51
# 12 33 63
# 12 34 55
# Current node 11, 34, interval 58
# is_traversable 10 33
# is_traversable 10 34
# is_traversable 10 35
# is_traversable 11 33
# is_traversable 11 34
# is_traversable 11 35
# is_traversable 12 33
# is_traversable 11 33
# is_traversable 12 34
# is_traversable 12 34
# is_traversable 12 35
# is_traversable 11 35
# is_traversable 12 34
# 11 33 64
# 11 35 67
# 12 33 63
# 12 34 55
# 12 35 92
# Current node 11, 35, interval 67
# is_traversable 10 34
# is_traversable 10 35
# is_traversable 10 36
# is_traversable 11 34
# is_traversable 11 35
# is_traversable 11 36
# is_traversable 12 34
# is_traversable 11 34
# is_traversable 12 35
# is_traversable 12 35
# is_traversable 12 36
# is_traversable 11 36
# is_traversable 12 35
# 11 34 58
# 11 36 75
# 12 34 55
# 12 35 92
# 12 36 95
# Current node 11, 36, interval 75
# is_traversable 10 35
# is_traversable 10 36
# is_traversable 10 37
# is_traversable 11 35
# is_traversable 11 36
# is_traversable 11 37
# is_traversable 12 35
# is_traversable 11 35
# is_traversable 12 36
# is_traversable 12 36
# is_traversable 12 37
# is_traversable 11 37
# is_traversable 12 36
# 11 35 67
# 11 37 86
# 12 35 92
# 12 36 95
# 12 37 89
# Current node 11, 37, interval 86
# is_traversable 10 36
# is_traversable 10 37
# is_traversable 10 38
# is_traversable 11 38
# is_traversable 10 37
# is_traversable 11 36
# is_traversable 11 37
# is_traversable 11 38
# is_traversable 12 36
# is_traversable 11 36
# is_traversable 12 37
# is_traversable 12 37
# is_traversable 12 38
# is_traversable 11 38
# is_traversable 12 37
# 10 38 68
# 11 36 75
# 11 38 73
# 12 36 95
# 12 37 89
# 12 38 95
# Current node 10, 38, interval 68
# is_traversable 9 37
# is_traversable 9 38
# is_traversable 9 39
# is_traversable 10 39
# is_traversable 9 38
# is_traversable 10 37
# is_traversable 10 38
# is_traversable 10 39
# is_traversable 11 37
# is_traversable 10 37
# is_traversable 11 38
# is_traversable 11 38
# is_traversable 11 39
# is_traversable 10 39
# is_traversable 11 38
# 9 38 39
# 9 39 44
# 10 39 58
# 11 37 86
# 11 38 73
# 11 39 69
# Current node 9, 39, interval 44
# is_traversable 8 38
# is_traversable 9 38
# is_traversable 8 39
# is_traversable 8 39
# is_traversable 8 40
# is_traversable 9 40
# is_traversable 8 39
# is_traversable 9 38
# is_traversable 9 39
# is_traversable 9 40
# is_traversable 10 38
# is_traversable 9 38
# is_traversable 10 39
# is_traversable 10 39
# is_traversable 10 40
# is_traversable 9 40
# is_traversable 10 39
# 8 38 33
# 8 39 25
# 8 40 38
# 9 38 39
# 9 40 49
# 10 38 68
# 10 39 58
# 10 40 55
# Current node 8, 40, interval 38
# is_traversable 7 39
# is_traversable 8 39
# is_traversable 7 40
# is_traversable 7 40
# is_traversable 7 41
# is_traversable 8 41
# is_traversable 7 40
# is_traversable 8 39
# is_traversable 8 40
# is_traversable 8 41
# is_traversable 9 39
# is_traversable 8 39
# is_traversable 9 40
# is_traversable 9 40
# is_traversable 9 41
# is_traversable 8 41
# is_traversable 9 40
# 7 39 50
# 7 40 39
# 7 41 47
# 8 39 25
# 8 41 31
# 9 39 44
# 9 40 49
# 9 41 39
# Current node 7, 41, interval 47
# is_traversable 6 40
# is_traversable 7 40
# is_traversable 6 41
# is_traversable 6 41
# is_traversable 6 42
# is_traversable 7 42
# is_traversable 6 41
# is_traversable 7 40
# is_traversable 7 41
# is_traversable 7 42
# is_traversable 8 40
# is_traversable 7 40
# is_traversable 8 41
# is_traversable 8 41
# is_traversable 8 42
# is_traversable 7 42
# is_traversable 8 41
# 6 40 45
# 6 41 48
# 6 42 44
# 7 40 39
# 7 42 59
# 8 40 38
# 8 41 31
# 8 42 38
# Current node 6, 42, interval 44
# is_traversable 5 41
# is_traversable 6 41
# is_traversable 5 42
# is_traversable 5 42
# is_traversable 5 43
# is_traversable 6 43
# is_traversable 5 42
# is_traversable 6 41
# is_traversable 6 42
# is_traversable 6 43
# is_traversable 7 41
# is_traversable 6 41
# is_traversable 7 42
# is_traversable 7 42
# is_traversable 7 43
# is_traversable 6 43
# is_traversable 7 42
# 5 41 65
# 5 42 44
# 5 43 43
# 6 41 48
# 6 43 38
# 7 41 47
# 7 42 59
# 7 43 35
# Current node 6, 43, interval 38
# is_traversable 5 42
# is_traversable 6 42
# is_traversable 5 43
# is_traversable 5 43
# is_traversable 5 44
# is_traversable 6 42
# is_traversable 6 43
# is_traversable 6 44
# is_traversable 7 42
# is_traversable 6 42
# is_traversable 7 43
# is_traversable 7 43
# is_traversable 7 44
# is_traversable 6 44
# is_traversable 7 43
# 5 42 44
# 5 43 43
# 6 42 44
# 6 44 65
# 7 42 59
# 7 43 35
# 7 44 64
# Current node 6, 44, interval 65
# is_traversable 5 43
# is_traversable 6 43
# is_traversable 5 44
# is_traversable 5 44
# is_traversable 5 45
# is_traversable 6 43
# is_traversable 6 44
# is_traversable 6 45
# is_traversable 7 43
# is_traversable 6 43
# is_traversable 7 44
# is_traversable 7 44
# is_traversable 7 45
# is_traversable 6 45
# is_traversable 7 44
# 5 43 43
# 6 43 38
# 6 45 55
# 7 43 35
# 7 44 64
# 7 45 73
# Current node 6, 45, interval 55
# is_traversable 5 44
# is_traversable 5 45
# is_traversable 5 46
# is_traversable 6 44
# is_traversable 6 45
# is_traversable 6 46
# is_traversable 7 44
# is_traversable 6 44
# is_traversable 7 45
# is_traversable 7 45
# is_traversable 7 46
# is_traversable 6 46
# is_traversable 7 45
# 6 44 65
# 7 44 64
# 7 45 73
# 7 46 60
# Current node 6, 41, interval 48
# is_traversable 5 40
# is_traversable 6 40
# is_traversable 5 41
# is_traversable 5 41
# is_traversable 5 42
# is_traversable 6 42
# is_traversable 5 41
# is_traversable 6 40
# is_traversable 6 41
# is_traversable 6 42
# is_traversable 7 40
# is_traversable 6 40
# is_traversable 7 41
# is_traversable 7 41
# is_traversable 7 42
# is_traversable 6 42
# is_traversable 7 41
# 5 40 57
# 5 41 65
# 5 42 44
# 6 40 45
# 6 42 44
# 7 40 39
# 7 41 47
# 7 42 59
# Current node 7, 42, interval 59
# is_traversable 6 41
# is_traversable 7 41
# is_traversable 6 42
# is_traversable 6 42
# is_traversable 6 43
# is_traversable 7 43
# is_traversable 6 42
# is_traversable 7 41
# is_traversable 7 42
# is_traversable 7 43
# is_traversable 8 41
# is_traversable 7 41
# is_traversable 8 42
# is_traversable 8 42
# is_traversable 8 43
# is_traversable 7 43
# is_traversable 8 42
# 6 41 48
# 6 42 44
# 6 43 38
# 7 41 47
# 7 43 35
# 8 41 31
# 8 42 38
# 8 43 24
# Current node 7, 43, interval 35
# is_traversable 6 42
# is_traversable 7 42
# is_traversable 6 43
# is_traversable 6 43
# is_traversable 6 44
# is_traversable 7 44
# is_traversable 6 43
# is_traversable 7 42
# is_traversable 7 43
# is_traversable 7 44
# is_traversable 8 42
# is_traversable 7 42
# is_traversable 8 43
# is_traversable 8 43
# is_traversable 8 44
# is_traversable 7 44
# is_traversable 8 43
# 6 42 44
# 6 43 38
# 6 44 65
# 7 42 59
# 7 44 64
# 8 42 38
# 8 43 24
# 8 44 39
# Current node 7, 44, interval 64
# is_traversable 6 43
# is_traversable 7 43
# is_traversable 6 44
# is_traversable 6 44
# is_traversable 6 45
# is_traversable 7 45
# is_traversable 6 44
# is_traversable 7 43
# is_traversable 7 44
# is_traversable 7 45
# is_traversable 8 43
# is_traversable 7 43
# is_traversable 8 44
# is_traversable 8 44
# is_traversable 8 45
# is_traversable 7 45
# is_traversable 8 44
# 6 43 38
# 6 44 65
# 6 45 55
# 7 43 35
# 7 45 73
# 8 43 24
# 8 44 39
# 8 45 47
# Current node 7, 45, interval 73
# is_traversable 6 44
# is_traversable 7 44
# is_traversable 6 45
# is_traversable 6 45
# is_traversable 6 46
# is_traversable 7 44
# is_traversable 7 45
# is_traversable 7 46
# is_traversable 8 44
# is_traversable 7 44
# is_traversable 8 45
# is_traversable 8 45
# is_traversable 8 46
# is_traversable 7 46
# is_traversable 8 45
# 6 44 65
# 6 45 55
# 7 44 64
# 7 46 60
# 8 44 39
# 8 45 47
# 8 46 29
# Current node 7, 46, interval 60
# is_traversable 6 45
# is_traversable 7 45
# is_traversable 6 46
# is_traversable 6 46
# is_traversable 6 47
# is_traversable 7 45
# is_traversable 7 46
# is_traversable 7 47
# is_traversable 8 45
# is_traversable 7 45
# is_traversable 8 46
# is_traversable 8 46
# is_traversable 8 47
# 6 45 55
# 7 45 73
# 8 45 47
# 8 46 29
# Current node 7, 40, interval 39
# is_traversable 6 39
# is_traversable 7 39
# is_traversable 6 40
# is_traversable 6 40
# is_traversable 6 41
# is_traversable 7 41
# is_traversable 6 40
# is_traversable 7 39
# is_traversable 7 40
# is_traversable 7 41
# is_traversable 8 39
# is_traversable 7 39
# is_traversable 8 40
# is_traversable 8 40
# is_traversable 8 41
# is_traversable 7 41
# is_traversable 8 40
# 6 39 55
# 6 40 45
# 6 41 48
# 7 39 50
# 7 41 47
# 8 39 25
# 8 40 38
# 8 41 31
# Current node 6, 40, interval 45
# is_traversable 5 39
# is_traversable 6 39
# is_traversable 5 40
# is_traversable 5 40
# is_traversable 5 41
# is_traversable 6 41
# is_traversable 5 40
# is_traversable 6 39
# is_traversable 6 40
# is_traversable 6 41
# is_traversable 7 39
# is_traversable 6 39
# is_traversable 7 40
# is_traversable 7 40
# is_traversable 7 41
# is_traversable 6 41
# is_traversable 7 40
# 5 39 59
# 5 40 57
# 5 41 65
# 6 39 55
# 6 41 48
# 7 39 50
# 7 40 39
# 7 41 47
# Current node 8, 41, interval 31
# is_traversable 7 40
# is_traversable 8 40
# is_traversable 7 41
# is_traversable 7 41
# is_traversable 7 42
# is_traversable 8 42
# is_traversable 7 41
# is_traversable 8 40
# is_traversable 8 41
# is_traversable 8 42
# is_traversable 9 40
# is_traversable 8 40
# is_traversable 9 41
# is_traversable 9 41
# is_traversable 9 42
# is_traversable 8 42
# is_traversable 9 41
# 7 40 39
# 7 41 47
# 7 42 59
# 8 40 38
# 8 42 38
# 9 40 49
# 9 41 39
# 9 42 36
# Current node 8, 42, interval 38
# is_traversable 7 41
# is_traversable 8 41
# is_traversable 7 42
# is_traversable 7 42
# is_traversable 7 43
# is_traversable 8 43
# is_traversable 7 42
# is_traversable 8 41
# is_traversable 8 42
# is_traversable 8 43
# is_traversable 9 41
# is_traversable 8 41
# is_traversable 9 42
# is_traversable 9 42
# is_traversable 9 43
# is_traversable 8 43
# is_traversable 9 42
# 7 41 47
# 7 42 59
# 7 43 35
# 8 41 31
# 8 43 24
# 9 41 39
# 9 42 36
# 9 43 26
# Current node 8, 43, interval 24
# is_traversable 7 42
# is_traversable 8 42
# is_traversable 7 43
# is_traversable 7 43
# is_traversable 7 44
# is_traversable 8 44
# is_traversable 7 43
# is_traversable 8 42
# is_traversable 8 43
# is_traversable 8 44
# is_traversable 9 42
# is_traversable 8 42
# is_traversable 9 43
# is_traversable 9 43
# is_traversable 9 44
# is_traversable 8 44
# is_traversable 9 43
# 7 42 59
# 7 43 35
# 7 44 64
# 8 42 38
# 8 44 39
# 9 42 36
# 9 43 26
# 9 44 44
# Current node 8, 44, interval 39
# is_traversable 7 43
# is_traversable 8 43
# is_traversable 7 44
# is_traversable 7 44
# is_traversable 7 45
# is_traversable 8 45
# is_traversable 7 44
# is_traversable 8 43
# is_traversable 8 44
# is_traversable 8 45
# is_traversable 9 43
# is_traversable 8 43
# is_traversable 9 44
# is_traversable 9 44
# is_traversable 9 45
# is_traversable 8 45
# is_traversable 9 44
# 7 43 35
# 7 44 64
# 7 45 73
# 8 43 24
# 8 45 47
# 9 43 26
# 9 44 44
# 9 45 44
# Current node 8, 45, interval 47
# is_traversable 7 44
# is_traversable 8 44
# is_traversable 7 45
# is_traversable 7 45
# is_traversable 7 46
# is_traversable 8 46
# is_traversable 7 45
# is_traversable 8 44
# is_traversable 8 45
# is_traversable 8 46
# is_traversable 9 44
# is_traversable 8 44
# is_traversable 9 45
# is_traversable 9 45
# is_traversable 9 46
# is_traversable 8 46
# is_traversable 9 45
# 7 44 64
# 7 45 73
# 7 46 60
# 8 44 39
# 8 46 29
# 9 44 44
# 9 45 44
# 9 46 30
# Current node 8, 46, interval 29
# is_traversable 7 45
# is_traversable 8 45
# is_traversable 7 46
# is_traversable 7 46
# is_traversable 7 47
# is_traversable 8 45
# is_traversable 8 46
# is_traversable 8 47
# is_traversable 9 45
# is_traversable 8 45
# is_traversable 9 46
# is_traversable 9 46
# is_traversable 9 47
# 7 45 73
# 7 46 60
# 8 45 47
# 9 45 44
# 9 46 30
# Current node 8, 39, interval 25
# is_traversable 7 38
# is_traversable 8 38
# is_traversable 7 39
# is_traversable 7 39
# is_traversable 7 40
# is_traversable 8 40
# is_traversable 7 39
# is_traversable 8 38
# is_traversable 8 39
# is_traversable 8 40
# is_traversable 9 38
# is_traversable 8 38
# is_traversable 9 39
# is_traversable 9 39
# is_traversable 9 40
# is_traversable 8 40
# is_traversable 9 39
# 7 38 48
# 7 39 50
# 7 40 39
# 8 38 33
# 8 40 38
# 9 38 39
# 9 39 44
# 9 40 49
# Current node 7, 39, interval 50
# is_traversable 6 38
# is_traversable 7 38
# is_traversable 6 39
# is_traversable 6 39
# is_traversable 6 40
# is_traversable 7 40
# is_traversable 6 39
# is_traversable 7 38
# is_traversable 7 39
# is_traversable 7 40
# is_traversable 8 38
# is_traversable 7 38
# is_traversable 8 39
# is_traversable 8 39
# is_traversable 8 40
# is_traversable 7 40
# is_traversable 8 39
# 6 38 50
# 6 39 55
# 6 40 45
# 7 38 48
# 7 40 39
# 8 38 33
# 8 39 25
# 8 40 38
# Current node 6, 39, interval 55
# is_traversable 5 38
# is_traversable 6 38
# is_traversable 5 39
# is_traversable 5 39
# is_traversable 5 40
# is_traversable 6 40
# is_traversable 5 39
# is_traversable 6 38
# is_traversable 6 39
# is_traversable 6 40
# is_traversable 7 38
# is_traversable 6 38
# is_traversable 7 39
# is_traversable 7 39
# is_traversable 7 40
# is_traversable 6 40
# is_traversable 7 39
# 5 38 62
# 5 39 59
# 5 40 57
# 6 38 50
# 6 40 45
# 7 38 48
# 7 39 50
# 7 40 39
# Current node 9, 40, interval 49
# is_traversable 8 39
# is_traversable 9 39
# is_traversable 8 40
# is_traversable 8 40
# is_traversable 8 41
# is_traversable 9 41
# is_traversable 8 40
# is_traversable 9 39
# is_traversable 9 40
# is_traversable 9 41
# is_traversable 10 39
# is_traversable 9 39
# is_traversable 10 40
# is_traversable 10 40
# is_traversable 10 41
# is_traversable 9 41
# is_traversable 10 40
# 8 39 25
# 8 40 38
# 8 41 31
# 9 39 44
# 9 41 39
# 10 39 58
# 10 40 55
# 10 41 45
# Current node 9, 41, interval 39
# is_traversable 8 40
# is_traversable 9 40
# is_traversable 8 41
# is_traversable 8 41
# is_traversable 8 42
# is_traversable 9 42
# is_traversable 8 41
# is_traversable 9 40
# is_traversable 9 41
# is_traversable 9 42
# is_traversable 10 40
# is_traversable 9 40
# is_traversable 10 41
# is_traversable 10 41
# is_traversable 10 42
# is_traversable 9 42
# is_traversable 10 41
# 8 40 38
# 8 41 31
# 8 42 38
# 9 40 49
# 9 42 36
# 10 40 55
# 10 41 45
# 10 42 46
# Current node 9, 42, interval 36
# is_traversable 8 41
# is_traversable 9 41
# is_traversable 8 42
# is_traversable 8 42
# is_traversable 8 43
# is_traversable 9 43
# is_traversable 8 42
# is_traversable 9 41
# is_traversable 9 42
# is_traversable 9 43
# is_traversable 10 41
# is_traversable 9 41
# is_traversable 10 42
# is_traversable 10 42
# is_traversable 10 43
# is_traversable 9 43
# is_traversable 10 42
# 8 41 31
# 8 42 38
# 8 43 24
# 9 41 39
# 9 43 26
# 10 41 45
# 10 42 46
# 10 43 51
# Current node 9, 43, interval 26
# is_traversable 8 42
# is_traversable 9 42
# is_traversable 8 43
# is_traversable 8 43
# is_traversable 8 44
# is_traversable 9 44
# is_traversable 8 43
# is_traversable 9 42
# is_traversable 9 43
# is_traversable 9 44
# is_traversable 10 42
# is_traversable 9 42
# is_traversable 10 43
# is_traversable 10 43
# is_traversable 10 44
# is_traversable 9 44
# is_traversable 10 43
# 8 42 38
# 8 43 24
# 8 44 39
# 9 42 36
# 9 44 44
# 10 42 46
# 10 43 51
# 10 44 53
# Current node 9, 44, interval 44
# is_traversable 8 43
# is_traversable 9 43
# is_traversable 8 44
# is_traversable 8 44
# is_traversable 8 45
# is_traversable 9 45
# is_traversable 8 44
# is_traversable 9 43
# is_traversable 9 44
# is_traversable 9 45
# is_traversable 10 43
# is_traversable 9 43
# is_traversable 10 44
# is_traversable 10 44
# is_traversable 10 45
# is_traversable 9 45
# is_traversable 10 44
# 8 43 24
# 8 44 39
# 8 45 47
# 9 43 26
# 9 45 44
# 10 43 51
# 10 44 53
# 10 45 56
# Current node 9, 45, interval 44
# is_traversable 8 44
# is_traversable 9 44
# is_traversable 8 45
# is_traversable 8 45
# is_traversable 8 46
# is_traversable 9 46
# is_traversable 8 45
# is_traversable 9 44
# is_traversable 9 45
# is_traversable 9 46
# is_traversable 10 44
# is_traversable 9 44
# is_traversable 10 45
# is_traversable 10 45
# is_traversable 10 46
# 8 44 39
# 8 45 47
# 8 46 29
# 9 44 44
# 9 46 30
# 10 44 53
# 10 45 56
# Current node 9, 46, interval 30
# is_traversable 8 45
# is_traversable 9 45
# is_traversable 8 46
# is_traversable 8 46
# is_traversable 8 47
# is_traversable 9 45
# is_traversable 9 46
# is_traversable 9 47
# is_traversable 10 45
# is_traversable 9 45
# is_traversable 10 46
# is_traversable 10 46
# is_traversable 10 47
# 8 45 47
# 8 46 29
# 9 45 44
# 10 45 56
# Current node 9, 38, interval 39
# is_traversable 8 37
# is_traversable 8 38
# is_traversable 8 39
# is_traversable 9 39
# is_traversable 8 38
# is_traversable 9 37
# is_traversable 9 38
# is_traversable 9 39
# is_traversable 10 37
# is_traversable 10 38
# is_traversable 10 39
# is_traversable 9 39
# is_traversable 10 38
# 8 38 33
# 8 39 25
# 9 39 44
# 10 38 68
# 10 39 58
# Current node 8, 38, interval 33
# is_traversable 7 37
# is_traversable 8 37
# is_traversable 7 38
# is_traversable 7 38
# is_traversable 7 39
# is_traversable 8 39
# is_traversable 7 38
# is_traversable 8 37
# is_traversable 8 38
# is_traversable 8 39
# is_traversable 9 37
# is_traversable 9 38
# is_traversable 9 39
# is_traversable 8 39
# is_traversable 9 38
# 7 37 47
# 7 38 48
# 7 39 50
# 8 39 25
# 9 38 39
# 9 39 44
# Current node 7, 38, interval 48
# is_traversable 6 37
# is_traversable 7 37
# is_traversable 6 38
# is_traversable 6 38
# is_traversable 6 39
# is_traversable 7 39
# is_traversable 6 38
# is_traversable 7 37
# is_traversable 7 38
# is_traversable 7 39
# is_traversable 8 37
# is_traversable 8 38
# is_traversable 8 39
# is_traversable 7 39
# is_traversable 8 38
# 6 37 64
# 6 38 50
# 6 39 55
# 7 37 47
# 7 39 50
# 8 38 33
# 8 39 25
# Current node 6, 38, interval 50
# is_traversable 5 37
# is_traversable 6 37
# is_traversable 5 38
# is_traversable 5 38
# is_traversable 5 39
# is_traversable 6 39
# is_traversable 5 38
# is_traversable 6 37
# is_traversable 6 38
# is_traversable 6 39
# is_traversable 7 37
# is_traversable 6 37
# is_traversable 7 38
# is_traversable 7 38
# is_traversable 7 39
# is_traversable 6 39
# is_traversable 7 38
# 5 37 69
# 5 38 62
# 5 39 59
# 6 37 64
# 6 39 55
# 7 37 47
# 7 38 48
# 7 39 50
# Current node 10, 39, interval 58
# is_traversable 9 38
# is_traversable 10 38
# is_traversable 9 39
# is_traversable 9 39
# is_traversable 9 40
# is_traversable 10 40
# is_traversable 9 39
# is_traversable 10 38
# is_traversable 10 39
# is_traversable 10 40
# is_traversable 11 38
# is_traversable 10 38
# is_traversable 11 39
# is_traversable 11 39
# is_traversable 11 40
# is_traversable 10 40
# is_traversable 11 39
# 9 38 39
# 9 39 44
# 9 40 49
# 10 38 68
# 10 40 55
# 11 38 73
# 11 39 69
# 11 40 68
# Current node 10, 40, interval 55
# is_traversable 9 39
# is_traversable 10 39
# is_traversable 9 40
# is_traversable 9 40
# is_traversable 9 41
# is_traversable 10 41
# is_traversable 9 40
# is_traversable 10 39
# is_traversable 10 40
# is_traversable 10 41
# is_traversable 11 39
# is_traversable 10 39
# is_traversable 11 40
# is_traversable 11 40
# is_traversable 11 41
# is_traversable 10 41
# is_traversable 11 40
# 9 39 44
# 9 40 49
# 9 41 39
# 10 39 58
# 10 41 45
# 11 39 69
# 11 40 68
# 11 41 57
# Current node 10, 41, interval 45
# is_traversable 9 40
# is_traversable 10 40
# is_traversable 9 41
# is_traversable 9 41
# is_traversable 9 42
# is_traversable 10 42
# is_traversable 9 41
# is_traversable 10 40
# is_traversable 10 41
# is_traversable 10 42
# is_traversable 11 40
# is_traversable 10 40
# is_traversable 11 41
# is_traversable 11 41
# is_traversable 11 42
# is_traversable 10 42
# is_traversable 11 41
# 9 40 49
# 9 41 39
# 9 42 36
# 10 40 55
# 10 42 46
# 11 40 68
# 11 41 57
# 11 42 42
# Current node 10, 42, interval 46
# is_traversable 9 41
# is_traversable 10 41
# is_traversable 9 42
# is_traversable 9 42
# is_traversable 9 43
# is_traversable 10 43
# is_traversable 9 42
# is_traversable 10 41
# is_traversable 10 42
# is_traversable 10 43
# is_traversable 11 41
# is_traversable 10 41
# is_traversable 11 42
# is_traversable 11 42
# is_traversable 11 43
# is_traversable 10 43
# is_traversable 11 42
# 9 41 39
# 9 42 36
# 9 43 26
# 10 41 45
# 10 43 51
# 11 41 57
# 11 42 42
# 11 43 55
# Current node 10, 43, interval 51
# is_traversable 9 42
# is_traversable 10 42
# is_traversable 9 43
# is_traversable 9 43
# is_traversable 9 44
# is_traversable 10 44
# is_traversable 9 43
# is_traversable 10 42
# is_traversable 10 43
# is_traversable 10 44
# is_traversable 11 42
# is_traversable 10 42
# is_traversable 11 43
# is_traversable 11 43
# is_traversable 11 44
# is_traversable 10 44
# is_traversable 11 43
# 9 42 36
# 9 43 26
# 9 44 44
# 10 42 46
# 10 44 53
# 11 42 42
# 11 43 55
# 11 44 54
# Current node 10, 44, interval 53
# is_traversable 9 43
# is_traversable 10 43
# is_traversable 9 44
# is_traversable 9 44
# is_traversable 9 45
# is_traversable 10 45
# is_traversable 9 44
# is_traversable 10 43
# is_traversable 10 44
# is_traversable 10 45
# is_traversable 11 43
# is_traversable 10 43
# is_traversable 11 44
# is_traversable 11 44
# is_traversable 11 45
# is_traversable 10 45
# is_traversable 11 44
# 9 43 26
# 9 44 44
# 9 45 44
# 10 43 51
# 10 45 56
# 11 43 55
# 11 44 54
# 11 45 50
# Current node 10, 45, interval 56
# is_traversable 9 44
# is_traversable 10 44
# is_traversable 9 45
# is_traversable 9 45
# is_traversable 9 46
# is_traversable 10 46
# is_traversable 9 45
# is_traversable 10 44
# is_traversable 10 45
# is_traversable 10 46
# is_traversable 11 44
# is_traversable 10 44
# is_traversable 11 45
# is_traversable 11 45
# is_traversable 11 46
# 9 44 44
# 9 45 44
# 9 46 30
# 10 44 53
# 11 44 54
# 11 45 50
# Current node 11, 38, interval 73
# is_traversable 10 37
# is_traversable 10 38
# is_traversable 10 39
# is_traversable 11 39
# is_traversable 10 38
# is_traversable 11 37
# is_traversable 11 38
# is_traversable 11 39
# is_traversable 12 37
# is_traversable 11 37
# is_traversable 12 38
# is_traversable 12 38
# is_traversable 12 39
# is_traversable 11 39
# is_traversable 12 38
# 10 38 68
# 10 39 58
# 11 37 86
# 11 39 69
# 12 37 89
# 12 38 95
# 12 39 74
# Current node 11, 39, interval 69
# is_traversable 10 38
# is_traversable 11 38
# is_traversable 10 39
# is_traversable 10 39
# is_traversable 10 40
# is_traversable 11 40
# is_traversable 10 39
# is_traversable 11 38
# is_traversable 11 39
# is_traversable 11 40
# is_traversable 12 38
# is_traversable 11 38
# is_traversable 12 39
# is_traversable 12 39
# is_traversable 12 40
# is_traversable 11 40
# is_traversable 12 39
# 10 38 68
# 10 39 58
# 10 40 55
# 11 38 73
# 11 40 68
# 12 38 95
# 12 39 74
# 12 40 76
# Current node 11, 40, interval 68
# is_traversable 10 39
# is_traversable 11 39
# is_traversable 10 40
# is_traversable 10 40
# is_traversable 10 41
# is_traversable 11 41
# is_traversable 10 40
# is_traversable 11 39
# is_traversable 11 40
# is_traversable 11 41
# is_traversable 12 39
# is_traversable 11 39
# is_traversable 12 40
# is_traversable 12 40
# is_traversable 12 41
# is_traversable 11 41
# is_traversable 12 40
# 10 39 58
# 10 40 55
# 10 41 45
# 11 39 69
# 11 41 57
# 12 39 74
# 12 40 76
# 12 41 70
# Current node 11, 41, interval 57
# is_traversable 10 40
# is_traversable 11 40
# is_traversable 10 41
# is_traversable 10 41
# is_traversable 10 42
# is_traversable 11 42
# is_traversable 10 41
# is_traversable 11 40
# is_traversable 11 41
# is_traversable 11 42
# is_traversable 12 40
# is_traversable 11 40
# is_traversable 12 41
# is_traversable 12 41
# is_traversable 12 42
# is_traversable 11 42
# is_traversable 12 41
# 10 40 55
# 10 41 45
# 10 42 46
# 11 40 68
# 11 42 42
# 12 40 76
# 12 41 70
# 12 42 77
# Current node 11, 42, interval 42
# is_traversable 10 41
# is_traversable 11 41
# is_traversable 10 42
# is_traversable 10 42
# is_traversable 10 43
# is_traversable 11 43
# is_traversable 10 42
# is_traversable 11 41
# is_traversable 11 42
# is_traversable 11 43
# is_traversable 12 41
# is_traversable 11 41
# is_traversable 12 42
# is_traversable 12 42
# is_traversable 12 43
# is_traversable 11 43
# is_traversable 12 42
# 10 41 45
# 10 42 46
# 10 43 51
# 11 41 57
# 11 43 55
# 12 41 70
# 12 42 77
# 12 43 78
# Current node 11, 43, interval 55
# is_traversable 10 42
# is_traversable 11 42
# is_traversable 10 43
# is_traversable 10 43
# is_traversable 10 44
# is_traversable 11 44
# is_traversable 10 43
# is_traversable 11 42
# is_traversable 11 43
# is_traversable 11 44
# is_traversable 12 42
# is_traversable 11 42
# is_traversable 12 43
# is_traversable 12 43
# is_traversable 12 44
# is_traversable 11 44
# is_traversable 12 43
# 10 42 46
# 10 43 51
# 10 44 53
# 11 42 42
# 11 44 54
# 12 42 77
# 12 43 78
# 12 44 71
# Current node 11, 44, interval 54
# is_traversable 10 43
# is_traversable 11 43
# is_traversable 10 44
# is_traversable 10 44
# is_traversable 10 45
# is_traversable 11 45
# is_traversable 10 44
# is_traversable 11 43
# is_traversable 11 44
# is_traversable 11 45
# is_traversable 12 43
# is_traversable 11 43
# is_traversable 12 44
# is_traversable 12 44
# is_traversable 12 45
# is_traversable 11 45
# is_traversable 12 44
# 10 43 51
# 10 44 53
# 10 45 56
# 11 43 55
# 11 45 50
# 12 43 78
# 12 44 71
# 12 45 66
# Current node 11, 45, interval 50
# is_traversable 10 44
# is_traversable 11 44
# is_traversable 10 45
# is_traversable 10 45
# is_traversable 10 46
# is_traversable 11 44
# is_traversable 11 45
# is_traversable 11 46
# is_traversable 12 44
# is_traversable 11 44
# is_traversable 12 45
# is_traversable 12 45
# is_traversable 12 46
# is_traversable 11 46
# is_traversable 12 45
# 10 44 53
# 10 45 56
# 11 44 54
# 12 44 71
# 12 45 66
# 12 46 80
# Current node 11, 31, interval 42
# is_traversable 10 30
# is_traversable 10 31
# is_traversable 10 32
# is_traversable 11 30
# is_traversable 11 31
# is_traversable 11 32
# is_traversable 12 30
# is_traversable 11 30
# is_traversable 12 31
# is_traversable 12 31
# is_traversable 12 32
# is_traversable 11 32
# is_traversable 12 31
# 11 30 36
# 11 32 40
# 12 30 43
# 12 31 60
# 12 32 51
# Current node 12, 32, interval 51
# is_traversable 11 31
# is_traversable 12 31
# is_traversable 11 32
# is_traversable 11 32
# is_traversable 11 33
# is_traversable 12 33
# is_traversable 11 32
# is_traversable 12 31
# is_traversable 12 32
# is_traversable 12 33
# is_traversable 13 31
# is_traversable 12 31
# is_traversable 13 32
# is_traversable 13 32
# is_traversable 13 33
# is_traversable 12 33
# is_traversable 13 32
# 11 31 42
# 11 32 40
# 11 33 64
# 12 31 60
# 12 33 63
# 13 31 37
# 13 32 28
# 13 33 31
# Current node 12, 33, interval 63
# is_traversable 11 32
# is_traversable 12 32
# is_traversable 11 33
# is_traversable 11 33
# is_traversable 11 34
# is_traversable 12 34
# is_traversable 11 33
# is_traversable 12 32
# is_traversable 12 33
# is_traversable 12 34
# is_traversable 13 32
# is_traversable 12 32
# is_traversable 13 33
# is_traversable 13 33
# is_traversable 13 34
# is_traversable 12 34
# is_traversable 13 33
# 11 32 40
# 11 33 64
# 11 34 58
# 12 32 51
# 12 34 55
# 13 32 28
# 13 33 31
# 13 34 31
# Current node 12, 34, interval 55
# is_traversable 11 33
# is_traversable 12 33
# is_traversable 11 34
# is_traversable 11 34
# is_traversable 11 35
# is_traversable 12 35
# is_traversable 11 34
# is_traversable 12 33
# is_traversable 12 34
# is_traversable 12 35
# is_traversable 13 33
# is_traversable 12 33
# is_traversable 13 34
# is_traversable 13 34
# is_traversable 13 35
# is_traversable 12 35
# is_traversable 13 34
# 11 33 64
# 11 34 58
# 11 35 67
# 12 33 63
# 12 35 92
# 13 33 31
# 13 34 31
# 13 35 80
# Current node 12, 35, interval 92
# is_traversable 11 34
# is_traversable 12 34
# is_traversable 11 35
# is_traversable 11 35
# is_traversable 11 36
# is_traversable 12 36
# is_traversable 11 35
# is_traversable 12 34
# is_traversable 12 35
# is_traversable 12 36
# is_traversable 13 34
# is_traversable 12 34
# is_traversable 13 35
# is_traversable 13 35
# is_traversable 13 36
# is_traversable 12 36
# is_traversable 13 35
# 11 34 58
# 11 35 67
# 11 36 75
# 12 34 55
# 12 36 95
# 13 34 31
# 13 35 80
# 13 36 81
# Current node 12, 36, interval 95
# is_traversable 11 35
# is_traversable 12 35
# is_traversable 11 36
# is_traversable 11 36
# is_traversable 11 37
# is_traversable 12 37
# is_traversable 11 36
# is_traversable 12 35
# is_traversable 12 36
# is_traversable 12 37
# is_traversable 13 35
# is_traversable 12 35
# is_traversable 13 36
# is_traversable 13 36
# is_traversable 13 37
# is_traversable 12 37
# is_traversable 13 36
# 11 35 67
# 11 36 75
# 11 37 86
# 12 35 92
# 12 37 89
# 13 35 80
# 13 36 81
# 13 37 74
# Current node 12, 37, interval 89
# is_traversable 11 36
# is_traversable 12 36
# is_traversable 11 37
# is_traversable 11 37
# is_traversable 11 38
# is_traversable 12 38
# is_traversable 11 37
# is_traversable 12 36
# is_traversable 12 37
# is_traversable 12 38
# is_traversable 13 36
# is_traversable 12 36
# is_traversable 13 37
# is_traversable 13 37
# is_traversable 13 38
# is_traversable 12 38
# is_traversable 13 37
# 11 36 75
# 11 37 86
# 11 38 73
# 12 36 95
# 12 38 95
# 13 36 81
# 13 37 74
# 13 38 61
# Current node 12, 38, interval 95
# is_traversable 11 37
# is_traversable 12 37
# is_traversable 11 38
# is_traversable 11 38
# is_traversable 11 39
# is_traversable 12 39
# is_traversable 11 38
# is_traversable 12 37
# is_traversable 12 38
# is_traversable 12 39
# is_traversable 13 37
# is_traversable 12 37
# is_traversable 13 38
# is_traversable 13 38
# is_traversable 13 39
# is_traversable 12 39
# is_traversable 13 38
# 11 37 86
# 11 38 73
# 11 39 69
# 12 37 89
# 12 39 74
# 13 37 74
# 13 38 61
# 13 39 57
# Current node 12, 39, interval 74
# is_traversable 11 38
# is_traversable 12 38
# is_traversable 11 39
# is_traversable 11 39
# is_traversable 11 40
# is_traversable 12 40
# is_traversable 11 39
# is_traversable 12 38
# is_traversable 12 39
# is_traversable 12 40
# is_traversable 13 38
# is_traversable 12 38
# is_traversable 13 39
# is_traversable 13 39
# is_traversable 13 40
# is_traversable 12 40
# is_traversable 13 39
# 11 38 73
# 11 39 69
# 11 40 68
# 12 38 95
# 12 40 76
# 13 38 61
# 13 39 57
# 13 40 80
# Current node 12, 40, interval 76
# is_traversable 11 39
# is_traversable 12 39
# is_traversable 11 40
# is_traversable 11 40
# is_traversable 11 41
# is_traversable 12 41
# is_traversable 11 40
# is_traversable 12 39
# is_traversable 12 40
# is_traversable 12 41
# is_traversable 13 39
# is_traversable 12 39
# is_traversable 13 40
# is_traversable 13 40
# is_traversable 13 41
# 11 39 69
# 11 40 68
# 11 41 57
# 12 39 74
# 12 41 70
# 13 39 57
# 13 40 80
# Current node 12, 41, interval 70
# is_traversable 11 40
# is_traversable 12 40
# is_traversable 11 41
# is_traversable 11 41
# is_traversable 11 42
# is_traversable 12 42
# is_traversable 11 41
# is_traversable 12 40
# is_traversable 12 41
# is_traversable 12 42
# is_traversable 13 40
# is_traversable 12 40
# is_traversable 13 41
# is_traversable 13 41
# is_traversable 13 42
# 11 40 68
# 11 41 57
# 11 42 42
# 12 40 76
# 12 42 77
# 13 40 80
# Current node 12, 42, interval 77
# is_traversable 11 41
# is_traversable 12 41
# is_traversable 11 42
# is_traversable 11 42
# is_traversable 11 43
# is_traversable 12 43
# is_traversable 11 42
# is_traversable 12 41
# is_traversable 12 42
# is_traversable 12 43
# is_traversable 13 41
# is_traversable 13 42
# is_traversable 13 43
# 11 41 57
# 11 42 42
# 11 43 55
# 12 41 70
# 12 43 78
# Current node 12, 43, interval 78
# is_traversable 11 42
# is_traversable 12 42
# is_traversable 11 43
# is_traversable 11 43
# is_traversable 11 44
# is_traversable 12 44
# is_traversable 11 43
# is_traversable 12 42
# is_traversable 12 43
# is_traversable 12 44
# is_traversable 13 42
# is_traversable 13 43
# is_traversable 13 44
# 11 42 42
# 11 43 55
# 11 44 54
# 12 42 77
# 12 44 71
# Current node 12, 44, interval 71
# is_traversable 11 43
# is_traversable 12 43
# is_traversable 11 44
# is_traversable 11 44
# is_traversable 11 45
# is_traversable 12 45
# is_traversable 11 44
# is_traversable 12 43
# is_traversable 12 44
# is_traversable 12 45
# is_traversable 13 43
# is_traversable 13 44
# is_traversable 13 45
# 11 43 55
# 11 44 54
# 11 45 50
# 12 43 78
# 12 45 66
# Current node 12, 45, interval 66
# is_traversable 11 44
# is_traversable 12 44
# is_traversable 11 45
# is_traversable 11 45
# is_traversable 11 46
# is_traversable 12 44
# is_traversable 12 45
# is_traversable 12 46
# is_traversable 13 44
# is_traversable 13 45
# is_traversable 13 46
# 11 44 54
# 11 45 50
# 12 44 71
# 12 46 80
# Current node 12, 46, interval 80
# is_traversable 11 45
# is_traversable 12 45
# is_traversable 11 46
# is_traversable 11 46
# is_traversable 11 47
# is_traversable 12 45
# is_traversable 12 46
# is_traversable 12 47
# is_traversable 13 45
# is_traversable 13 46
# is_traversable 13 47
# 11 45 50
# 12 45 66
# Current node 12, 30, interval 43
# is_traversable 11 29
# is_traversable 12 29
# is_traversable 11 30
# is_traversable 11 30
# is_traversable 11 31
# is_traversable 12 31
# is_traversable 11 30
# is_traversable 12 29
# is_traversable 12 30
# is_traversable 12 31
# is_traversable 13 29
# is_traversable 12 29
# is_traversable 13 30
# is_traversable 13 30
# is_traversable 13 31
# is_traversable 12 31
# is_traversable 13 30
# 11 29 34
# 11 30 36
# 11 31 42
# 12 29 55
# 12 31 60
# 13 29 40
# 13 30 22
# 13 31 37
# Current node 11, 30, interval 36
# is_traversable 10 29
# is_traversable 10 30
# is_traversable 10 31
# is_traversable 11 29
# is_traversable 11 30
# is_traversable 11 31
# is_traversable 12 29
# is_traversable 11 29
# is_traversable 12 30
# is_traversable 12 30
# is_traversable 12 31
# is_traversable 11 31
# is_traversable 12 30
# 11 29 34
# 11 31 42
# 12 29 55
# 12 30 43
# 12 31 60
# Current node 13, 31, interval 37
# is_traversable 12 30
# is_traversable 13 30
# is_traversable 12 31
# is_traversable 12 31
# is_traversable 12 32
# is_traversable 13 32
# is_traversable 12 31
# is_traversable 13 30
# is_traversable 13 31
# is_traversable 13 32
# is_traversable 14 30
# is_traversable 13 30
# is_traversable 14 31
# is_traversable 14 31
# is_traversable 14 32
# is_traversable 13 32
# is_traversable 14 31
# 12 30 43
# 12 31 60
# 12 32 51
# 13 30 22
# 13 32 28
# 14 30 57
# 14 31 50
# 14 32 38
# Current node 13, 32, interval 28
# is_traversable 12 31
# is_traversable 13 31
# is_traversable 12 32
# is_traversable 12 32
# is_traversable 12 33
# is_traversable 13 33
# is_traversable 12 32
# is_traversable 13 31
# is_traversable 13 32
# is_traversable 13 33
# is_traversable 14 31
# is_traversable 13 31
# is_traversable 14 32
# is_traversable 14 32
# is_traversable 14 33
# is_traversable 13 33
# is_traversable 14 32
# 12 31 60
# 12 32 51
# 12 33 63
# 13 31 37
# 13 33 31
# 14 31 50
# 14 32 38
# 14 33 45
# Current node 13, 33, interval 31
# is_traversable 12 32
# is_traversable 13 32
# is_traversable 12 33
# is_traversable 12 33
# is_traversable 12 34
# is_traversable 13 34
# is_traversable 12 33
# is_traversable 13 32
# is_traversable 13 33
# is_traversable 13 34
# is_traversable 14 32
# is_traversable 13 32
# is_traversable 14 33
# is_traversable 14 33
# is_traversable 14 34
# is_traversable 13 34
# is_traversable 14 33
# 12 32 51
# 12 33 63
# 12 34 55
# 13 32 28
# 13 34 31
# 14 32 38
# 14 33 45
# 14 34 44
# Current node 13, 34, interval 31
# is_traversable 12 33
# is_traversable 13 33
# is_traversable 12 34
# is_traversable 12 34
# is_traversable 12 35
# is_traversable 13 35
# is_traversable 12 34
# is_traversable 13 33
# is_traversable 13 34
# is_traversable 13 35
# is_traversable 14 33
# is_traversable 13 33
# is_traversable 14 34
# is_traversable 14 34
# is_traversable 14 35
# 12 33 63
# 12 34 55
# 12 35 92
# 13 33 31
# 13 35 80
# 14 33 45
# 14 34 44
# Current node 13, 35, interval 80
# is_traversable 12 34
# is_traversable 13 34
# is_traversable 12 35
# is_traversable 12 35
# is_traversable 12 36
# is_traversable 13 36
# is_traversable 12 35
# is_traversable 13 34
# is_traversable 13 35
# is_traversable 13 36
# is_traversable 14 34
# is_traversable 13 34
# is_traversable 14 35
# is_traversable 14 35
# is_traversable 14 36
# 12 34 55
# 12 35 92
# 12 36 95
# 13 34 31
# 13 36 81
# 14 34 44
# Current node 13, 36, interval 81
# is_traversable 12 35
# is_traversable 13 35
# is_traversable 12 36
# is_traversable 12 36
# is_traversable 12 37
# is_traversable 13 37
# is_traversable 12 36
# is_traversable 13 35
# is_traversable 13 36
# is_traversable 13 37
# is_traversable 14 35
# is_traversable 14 36
# is_traversable 14 37
# 12 35 92
# 12 36 95
# 12 37 89
# 13 35 80
# 13 37 74
# Current node 13, 37, interval 74
# is_traversable 12 36
# is_traversable 13 36
# is_traversable 12 37
# is_traversable 12 37
# is_traversable 12 38
# is_traversable 13 38
# is_traversable 12 37
# is_traversable 13 36
# is_traversable 13 37
# is_traversable 13 38
# is_traversable 14 36
# is_traversable 14 37
# is_traversable 14 38
# 12 36 95
# 12 37 89
# 12 38 95
# 13 36 81
# 13 38 61
# Current node 13, 38, interval 61
# is_traversable 12 37
# is_traversable 13 37
# is_traversable 12 38
# is_traversable 12 38
# is_traversable 12 39
# is_traversable 13 39
# is_traversable 12 38
# is_traversable 13 37
# is_traversable 13 38
# is_traversable 13 39
# is_traversable 14 37
# is_traversable 14 38
# is_traversable 14 39
# 12 37 89
# 12 38 95
# 12 39 74
# 13 37 74
# 13 39 57
# Current node 13, 39, interval 57
# is_traversable 12 38
# is_traversable 13 38
# is_traversable 12 39
# is_traversable 12 39
# is_traversable 12 40
# is_traversable 13 40
# is_traversable 12 39
# is_traversable 13 38
# is_traversable 13 39
# is_traversable 13 40
# is_traversable 14 38
# is_traversable 14 39
# is_traversable 14 40
# 12 38 95
# 12 39 74
# 12 40 76
# 13 38 61
# 13 40 80
# Current node 13, 40, interval 80
# is_traversable 12 39
# is_traversable 13 39
# is_traversable 12 40
# is_traversable 12 40
# is_traversable 12 41
# is_traversable 13 41
# is_traversable 12 40
# is_traversable 13 39
# is_traversable 13 40
# is_traversable 13 41
# is_traversable 14 39
# is_traversable 14 40
# is_traversable 14 41
# 12 39 74
# 12 40 76
# 12 41 70
# 13 39 57
# Current node 14, 30, interval 57
# is_traversable 13 29
# is_traversable 14 29
# is_traversable 13 30
# is_traversable 13 30
# is_traversable 13 31
# is_traversable 14 31
# is_traversable 13 30
# is_traversable 14 29
# is_traversable 14 30
# is_traversable 14 31
# is_traversable 15 29
# is_traversable 15 30
# is_traversable 15 31
# 13 29 40
# 13 30 22
# 13 31 37
# 14 29 71
# 14 31 50
# Current node 14, 31, interval 50
# is_traversable 13 30
# is_traversable 14 30
# is_traversable 13 31
# is_traversable 13 31
# is_traversable 13 32
# is_traversable 14 32
# is_traversable 13 31
# is_traversable 14 30
# is_traversable 14 31
# is_traversable 14 32
# is_traversable 15 30
# is_traversable 15 31
# is_traversable 15 32
# 13 30 22
# 13 31 37
# 13 32 28
# 14 30 57
# 14 32 38
# Current node 14, 32, interval 38
# is_traversable 13 31
# is_traversable 14 31
# is_traversable 13 32
# is_traversable 13 32
# is_traversable 13 33
# is_traversable 14 33
# is_traversable 13 32
# is_traversable 14 31
# is_traversable 14 32
# is_traversable 14 33
# is_traversable 15 31
# is_traversable 15 32
# is_traversable 15 33
# 13 31 37
# 13 32 28
# 13 33 31
# 14 31 50
# 14 33 45
# Current node 14, 33, interval 45
# is_traversable 13 32
# is_traversable 14 32
# is_traversable 13 33
# is_traversable 13 33
# is_traversable 13 34
# is_traversable 14 34
# is_traversable 13 33
# is_traversable 14 32
# is_traversable 14 33
# is_traversable 14 34
# is_traversable 15 32
# is_traversable 15 33
# is_traversable 15 34
# 13 32 28
# 13 33 31
# 13 34 31
# 14 32 38
# 14 34 44
# Current node 14, 34, interval 44
# is_traversable 13 33
# is_traversable 14 33
# is_traversable 13 34
# is_traversable 13 34
# is_traversable 13 35
# is_traversable 14 35
# is_traversable 13 34
# is_traversable 14 33
# is_traversable 14 34
# is_traversable 14 35
# is_traversable 15 33
# is_traversable 15 34
# is_traversable 15 35
# 13 33 31
# 13 34 31
# 13 35 80
# 14 33 45
# Current node 13, 29, interval 40
# is_traversable 12 28
# is_traversable 13 28
# is_traversable 12 29
# is_traversable 12 29
# is_traversable 12 30
# is_traversable 13 30
# is_traversable 12 29
# is_traversable 13 28
# is_traversable 13 29
# is_traversable 13 30
# is_traversable 14 28
# is_traversable 13 28
# is_traversable 14 29
# is_traversable 14 29
# is_traversable 14 30
# is_traversable 13 30
# is_traversable 14 29
# 12 28 47
# 12 29 55
# 12 30 43
# 13 28 26
# 13 30 22
# 14 28 47
# 14 29 71
# 14 30 57
# Current node 12, 29, interval 55
# is_traversable 11 28
# is_traversable 12 28
# is_traversable 11 29
# is_traversable 11 29
# is_traversable 11 30
# is_traversable 12 30
# is_traversable 11 29
# is_traversable 12 28
# is_traversable 12 29
# is_traversable 12 30
# is_traversable 13 28
# is_traversable 12 28
# is_traversable 13 29
# is_traversable 13 29
# is_traversable 13 30
# is_traversable 12 30
# is_traversable 13 29
# 11 28 38
# 11 29 34
# 11 30 36
# 12 28 47
# 12 30 43
# ...
# is_traversable 28 9
# is_traversable 28 9
# is_traversable 28 10
# is_traversable 29 10
# is_traversable 28 9
# is_traversable 29 8
# is_traversable 29 9
# is_traversable 29 10
# is_traversable 30 8
# is_traversable 29 8
# is_traversable 30 9
# is_traversable 30 9
# is_traversable 30 10
# is_traversable 29 10
# is_traversable 30 9
# 28 8 24
# 28 9 34
# 28 10 33
# 29 8 37
# 29 10 37
# 30 8 36
# 30 9 32
# 30 10 26
# Current node 28, 9, interval 34
# is_traversable 27 8
# is_traversable 28 8
# is_traversable 27 9
# is_traversable 27 9
# is_traversable 27 10
# is_traversable 28 10
# is_traversable 27 9
# is_traversable 28 8
# is_traversable 28 9
# is_traversable 28 10
# is_traversable 29 8
# is_traversable 28 8
# is_traversable 29 9
# is_traversable 29 9
# is_traversable 29 10
# is_traversable 28 10
# is_traversable 29 9
# 27 8 32
# 27 9 34
# 27 10 39
# 28 8 24
# 28 10 33
# 29 8 37
# 29 9 37
# 29 10 37
# Current node 27, 9, interval 34
# is_traversable 26 8
# is_traversable 26 9
# is_traversable 26 10
# is_traversable 27 10
# is_traversable 26 9
# is_traversable 27 8
# is_traversable 27 9
# is_traversable 27 10
# is_traversable 28 8
# is_traversable 27 8
# is_traversable 28 9
# is_traversable 28 9
# is_traversable 28 10
# is_traversable 27 10
# is_traversable 28 9
# 26 10 64
# 27 8 32
# 27 10 39
# 28 8 24
# 28 9 34
# 28 10 33
# Current node 33, 10, interval -1
# is_traversable 32 9
# is_traversable 33 9
# is_traversable 32 10
# is_traversable 32 10
# is_traversable 32 11
# is_traversable 33 11
# is_traversable 32 10
# is_traversable 33 9
# is_traversable 33 10
# is_traversable 33 11
# is_traversable 34 9
# is_traversable 33 9
# is_traversable 34 10
# is_traversable 34 10
# is_traversable 34 11
# is_traversable 33 11
# is_traversable 34 10
# 32 9 37
# 32 10 35
# 32 11 33
# 33 9 35
# 33 11 30
# 34 9 26
# 34 10 17
# 34 11 19
# Current node 33, 11, interval 30
# is_traversable 32 10
# is_traversable 33 10
# is_traversable 32 11
# is_traversable 32 11
# is_traversable 32 12
# is_traversable 33 12
# is_traversable 32 11
# is_traversable 33 10
# is_traversable 33 11
# is_traversable 33 12
# is_traversable 34 10
# is_traversable 33 10
# is_traversable 34 11
# is_traversable 34 11
# is_traversable 34 12
# is_traversable 33 12
# is_traversable 34 11
# 32 10 35
# 32 11 33
# 32 12 37
# 33 10 27
# 33 12 38
# 34 10 17
# 34 11 19
# 34 12 30
# Current node 33, 12, interval 38
# is_traversable 32 11
# is_traversable 33 11
# is_traversable 32 12
# is_traversable 32 12
# is_traversable 32 13
# is_traversable 33 13
# is_traversable 32 12
# is_traversable 33 11
# is_traversable 33 12
# is_traversable 33 13
# is_traversable 34 11
# is_traversable 33 11
# is_traversable 34 12
# is_traversable 34 12
# is_traversable 34 13
# is_traversable 33 13
# is_traversable 34 12
# 32 11 33
# 32 12 37
# 32 13 50
# 33 11 30
# 33 13 37
# 34 11 19
# 34 12 30
# 34 13 30
# Current node 33, 13, interval 37
# is_traversable 32 12
# is_traversable 33 12
# is_traversable 32 13
# is_traversable 32 13
# is_traversable 32 14
# is_traversable 33 14
# is_traversable 32 13
# is_traversable 33 12
# is_traversable 33 13
# is_traversable 33 14
# is_traversable 34 12
# is_traversable 33 12
# is_traversable 34 13
# is_traversable 34 13
# is_traversable 34 14
# is_traversable 33 14
# is_traversable 34 13
# 32 12 37
# 32 13 50
# 32 14 50
# 33 12 38
# 33 14 42
# 34 12 30
# 34 13 30
# 34 14 36
# Current node 33, 14, interval 42
# is_traversable 32 13
# is_traversable 33 13
# is_traversable 32 14
# is_traversable 32 14
# is_traversable 32 15
# is_traversable 33 13
# is_traversable 33 14
# is_traversable 33 15
# is_traversable 34 13
# is_traversable 33 13
# is_traversable 34 14
# is_traversable 34 14
# is_traversable 34 15
# 32 13 50
# 32 14 50
# 33 13 37
# 34 13 30
# 34 14 36
# Current node 5, 43, interval 43
# is_traversable 4 42
# is_traversable 5 42
# is_traversable 4 43
# is_traversable 4 43
# is_traversable 4 44
# is_traversable 5 42
# is_traversable 5 43
# is_traversable 5 44
# is_traversable 6 42
# is_traversable 5 42
# is_traversable 6 43
# is_traversable 6 43
# is_traversable 6 44
# is_traversable 5 44
# is_traversable 6 43
# 4 42 38
# 4 43 51
# 5 42 44
# 6 42 44
# 6 43 38
# 6 44 65
# Current node 5, 42, interval 44
# is_traversable 4 41
# is_traversable 5 41
# is_traversable 4 42
# is_traversable 4 42
# is_traversable 4 43
# is_traversable 5 43
# is_traversable 4 42
# is_traversable 5 41
# is_traversable 5 42
# is_traversable 5 43
# is_traversable 6 41
# is_traversable 5 41
# is_traversable 6 42
# is_traversable 6 42
# is_traversable 6 43
# is_traversable 5 43
# is_traversable 6 42
# 4 41 37
# 4 42 38
# 4 43 51
# 5 41 65
# 5 43 43
# 6 41 48
# 6 42 44
# 6 43 38
# Current node 5, 41, interval 65
# is_traversable 4 40
# is_traversable 4 41
# is_traversable 4 42
# is_traversable 5 42
# is_traversable 4 41
# is_traversable 5 40
# is_traversable 5 41
# is_traversable 5 42
# is_traversable 6 40
# is_traversable 5 40
# is_traversable 6 41
# is_traversable 6 41
# is_traversable 6 42
# is_traversable 5 42
# is_traversable 6 41
# 4 41 37
# 4 42 38
# 5 40 57
# 5 42 44
# 6 40 45
# 6 41 48
# 6 42 44
# Current node 5, 40, interval 57
# is_traversable 4 39
# is_traversable 4 40
# is_traversable 4 41
# is_traversable 5 41
# is_traversable 4 40
# is_traversable 5 39
# is_traversable 5 40
# is_traversable 5 41
# is_traversable 6 39
# is_traversable 5 39
# is_traversable 6 40
# is_traversable 6 40
# is_traversable 6 41
# is_traversable 5 41
# is_traversable 6 40
# 4 41 37
# 5 39 59
# 5 41 65
# 6 39 55
# 6 40 45
# 6 41 48
# Current node 5, 39, interval 59
# is_traversable 4 38
# is_traversable 4 39
# is_traversable 4 40
# is_traversable 5 38
# is_traversable 5 39
# is_traversable 5 40
# is_traversable 6 38
# is_traversable 5 38
# is_traversable 6 39
# is_traversable 6 39
# is_traversable 6 40
# is_traversable 5 40
# is_traversable 6 39
# 5 38 62
# 5 40 57
# 6 38 50
# 6 39 55
# 6 40 45
# Current node 6, 37, interval 64
# is_traversable 5 36
# is_traversable 6 36
# is_traversable 5 37
# is_traversable 5 37
# is_traversable 5 38
# is_traversable 6 38
# is_traversable 5 37
# is_traversable 6 36
# is_traversable 6 37
# is_traversable 6 38
# is_traversable 7 36
# is_traversable 6 36
# is_traversable 7 37
# is_traversable 7 37
# is_traversable 7 38
# is_traversable 6 38
# is_traversable 7 37
# 5 36 81
# 5 37 69
# 5 38 62
# 6 36 69
# 6 38 50
# 7 36 65
# 7 37 47
# 7 38 48
# Current node 5, 38, interval 62
# is_traversable 4 37
# is_traversable 5 37
# is_traversable 4 38
# is_traversable 4 38
# is_traversable 4 39
# is_traversable 5 37
# is_traversable 5 38
# is_traversable 5 39
# is_traversable 6 37
# is_traversable 5 37
# is_traversable 6 38
# is_traversable 6 38
# is_traversable 6 39
# is_traversable 5 39
# is_traversable 6 38
# 4 37 53
# 5 37 69
# 5 39 59
# 6 37 64
# 6 38 50
# 6 39 55
# Current node 7, 37, interval 47
# is_traversable 6 36
# is_traversable 7 36
# is_traversable 6 37
# is_traversable 6 37
# is_traversable 6 38
# is_traversable 7 38
# is_traversable 6 37
# is_traversable 7 36
# is_traversable 7 37
# is_traversable 7 38
# is_traversable 8 36
# is_traversable 8 37
# is_traversable 8 38
# is_traversable 7 38
# is_traversable 8 37
# 6 36 69
# 6 37 64
# 6 38 50
# 7 36 65
# 7 38 48
# 8 38 33
# Current node 27, 55, interval 101
# is_traversable 26 54
# is_traversable 27 54
# is_traversable 26 55
# is_traversable 26 55
# is_traversable 26 56
# is_traversable 27 54
# is_traversable 27 55
# is_traversable 27 56
# is_traversable 28 54
# is_traversable 27 54
# is_traversable 28 55
# is_traversable 28 55
# is_traversable 28 56
# is_traversable 27 56
# is_traversable 28 55
# 26 54 112
# 27 54 105
# 27 56 94
# 28 54 103
# 28 55 96
# 28 56 123
# Current node 27, 56, interval 94
# is_traversable 26 55
# is_traversable 26 56
# is_traversable 26 57
# is_traversable 27 55
# is_traversable 27 56
# is_traversable 27 57
# is_traversable 28 55
# is_traversable 27 55
# is_traversable 28 56
# is_traversable 28 56
# is_traversable 28 57
# is_traversable 27 57
# is_traversable 28 56
# 27 55 101
# 27 57 88
# 28 55 96
# 28 56 123
# 28 57 120
# Current node 27, 57, interval 88
# is_traversable 26 56
# is_traversable 26 57
# is_traversable 26 58
# is_traversable 27 58
# is_traversable 26 57
# is_traversable 27 56
# is_traversable 27 57
# is_traversable 27 58
# is_traversable 28 56
# is_traversable 27 56
# is_traversable 28 57
# is_traversable 28 57
# is_traversable 28 58
# is_traversable 27 58
# is_traversable 28 57
# 26 58 87
# 27 56 94
# 27 58 82
# 28 56 123
# 28 57 120
# 28 58 106
# Current node 26, 58, interval 87
# is_traversable 25 57
# is_traversable 25 58
# is_traversable 25 59
# is_traversable 26 59
# is_traversable 25 58
# is_traversable 26 57
# is_traversable 26 58
# is_traversable 26 59
# is_traversable 27 57
# is_traversable 26 57
# is_traversable 27 58
# is_traversable 27 58
# is_traversable 27 59
# is_traversable 26 59
# is_traversable 27 58
# 25 58 113
# 25 59 110
# 26 59 98
# 27 57 88
# 27 58 82
# 27 59 78
# Current node 25, 59, interval 110
# is_traversable 24 58
# is_traversable 25 58
# is_traversable 24 59
# is_traversable 24 59
# is_traversable 24 60
# is_traversable 25 60
# is_traversable 24 59
# is_traversable 25 58
# is_traversable 25 59
# is_traversable 25 60
# is_traversable 26 58
# is_traversable 25 58
# is_traversable 26 59
# is_traversable 26 59
# is_traversable 26 60
# is_traversable 25 60
# is_traversable 26 59
# 24 58 115
# 24 59 109
# 24 60 103
# 25 58 113
# 25 60 99
# 26 58 87
# 26 59 98
# 26 60 98
# Current node 24, 60, interval 103
# is_traversable 23 59
# is_traversable 24 59
# is_traversable 23 60
# is_traversable 23 60
# is_traversable 23 61
# is_traversable 24 61
# is_traversable 23 60
# is_traversable 24 59
# is_traversable 24 60
# is_traversable 24 61
# is_traversable 25 59
# is_traversable 24 59
# is_traversable 25 60
# is_traversable 25 60
# is_traversable 25 61
# is_traversable 24 61
# is_traversable 25 60
# 23 59 73
# 23 60 109
# 23 61 107
# 24 59 109
# 24 61 121
# 25 59 110
# 25 60 99
# 25 61 118
# Current node 23, 61, interval 107
# is_traversable 22 60
# is_traversable 23 60
# is_traversable 22 61
# is_traversable 22 61
# is_traversable 22 62
# is_traversable 23 62
# is_traversable 22 61
# is_traversable 23 60
# is_traversable 23 61
# is_traversable 23 62
# is_traversable 24 60
# is_traversable 23 60
# is_traversable 24 61
# is_traversable 24 61
# is_traversable 24 62
# is_traversable 23 62
# is_traversable 24 61
# 22 60 118
# 22 61 108
# 22 62 103
# 23 60 109
# 23 62 87
# 24 60 103
# 24 61 121
# 24 62 88
# Current node 22, 62, interval 103
# is_traversable 21 61
# is_traversable 22 61
# is_traversable 21 62
# is_traversable 21 62
# is_traversable 21 63
# is_traversable 22 63
# is_traversable 21 62
# is_traversable 22 61
# is_traversable 22 62
# is_traversable 22 63
# is_traversable 23 61
# is_traversable 22 61
# is_traversable 23 62
# is_traversable 23 62
# is_traversable 23 63
# 21 61 93
# 21 62 98
# 21 63 97
# 22 61 108
# 22 63 93
# 23 61 107
# 23 62 87
# Current node 21, 63, interval 97
# is_traversable 20 62
# is_traversable 21 62
# is_traversable 20 63
# is_traversable 20 63
# is_traversable 20 64
# is_traversable 21 64
# is_traversable 20 63
# is_traversable 21 62
# is_traversable 21 63
# is_traversable 21 64
# is_traversable 22 62
# is_traversable 21 62
# is_traversable 22 63
# is_traversable 22 63
# is_traversable 22 64
# 20 62 85
# 20 63 86
# 20 64 104
# 21 62 98
# 22 62 103
# 22 63 93
# Current node 20, 64, interval 104
# is_traversable 19 63
# is_traversable 20 63
# is_traversable 19 64
# is_traversable 19 64
# is_traversable 19 65
# is_traversable 20 65
# is_traversable 19 64
# is_traversable 20 63
# is_traversable 20 64
# is_traversable 20 65
# is_traversable 21 63
# is_traversable 20 63
# is_traversable 21 64
# is_traversable 21 64
# is_traversable 21 65
# 19 63 109
# 19 64 116
# 19 65 118
# 20 63 86
# 20 65 107
# 21 63 97
# Current node 19, 65, interval 118
# is_traversable 18 64
# is_traversable 19 64
# is_traversable 18 65
# is_traversable 18 65
# is_traversable 18 66
# is_traversable 19 66
# is_traversable 18 65
# is_traversable 19 64
# is_traversable 19 65
# is_traversable 19 66
# is_traversable 20 64
# is_traversable 19 64
# is_traversable 20 65
# is_traversable 20 65
# is_traversable 20 66
# is_traversable 19 66
# is_traversable 20 65
# 18 64 100
# 18 65 113
# 18 66 87
# 19 64 116
# 19 66 108
# 20 64 104
# 20 65 107
# 20 66 79
# Current node 18, 66, interval 87
# is_traversable 17 65
# is_traversable 18 65
# is_traversable 17 66
# is_traversable 17 66
# is_traversable 17 67
# is_traversable 18 67
# is_traversable 17 66
# is_traversable 18 65
# is_traversable 18 66
# is_traversable 18 67
# is_traversable 19 65
# is_traversable 18 65
# is_traversable 19 66
# is_traversable 19 66
# is_traversable 19 67
# is_traversable 18 67
# is_traversable 19 66
# 17 65 141
# 17 66 107
# 17 67 138
# 18 65 113
# 18 67 96
# 19 65 118
# 19 66 108
# 19 67 106
# Current node 17, 67, interval 138
# is_traversable 16 66
# is_traversable 17 66
# is_traversable 16 67
# is_traversable 16 67
# is_traversable 16 68
# is_traversable 17 68
# is_traversable 16 67
# is_traversable 17 66
# is_traversable 17 67
# is_traversable 17 68
# is_traversable 18 66
# is_traversable 17 66
# is_traversable 18 67
# is_traversable 18 67
# is_traversable 18 68
# 16 66 59
# 16 67 62
# 16 68 66
# 17 66 107
# 18 66 87
# 18 67 96
# Current node 16, 68, interval 66
# is_traversable 15 67
# is_traversable 16 67
# is_traversable 15 68
# is_traversable 15 68
# is_traversable 15 69
# is_traversable 16 69
# is_traversable 15 68
# is_traversable 16 67
# is_traversable 16 68
# is_traversable 16 69
# is_traversable 17 67
# is_traversable 16 67
# is_traversable 17 68
# is_traversable 17 68
# is_traversable 17 69
# 15 67 71
# 15 68 86
# 15 69 53
# 16 67 62
# 16 69 45
# 17 67 138
# Current node 15, 69, interval 53
# is_traversable 14 68
# is_traversable 15 68
# is_traversable 14 69
# is_traversable 14 69
# is_traversable 14 70
# is_traversable 15 68
# is_traversable 15 69
# is_traversable 15 70
# is_traversable 16 68
# is_traversable 15 68
# is_traversable 16 69
# is_traversable 16 69
# is_traversable 16 70
# is_traversable 15 70
# is_traversable 16 69
# 14 68 78
# 14 69 41
# 15 68 86
# 15 70 54
# 16 68 66
# 16 69 45
# 16 70 49
# Current node 14, 69, interval 41
# is_traversable 13 68
# is_traversable 14 68
# is_traversable 13 69
# is_traversable 13 69
# is_traversable 13 70
# is_traversable 14 68
# is_traversable 14 69
# is_traversable 14 70
# is_traversable 15 68
# is_traversable 14 68
# is_traversable 15 69
# is_traversable 15 69
# is_traversable 15 70
# is_traversable 14 70
# is_traversable 15 69
# 13 68 58
# 13 69 40
# 14 68 78
# 15 68 86
# 15 69 53
# 15 70 54
# Current node 13, 69, interval 40
# is_traversable 12 68
# is_traversable 13 68
# is_traversable 12 69
# is_traversable 12 69
# is_traversable 12 70
# is_traversable 13 68
# is_traversable 13 69
# is_traversable 13 70
# is_traversable 14 68
# is_traversable 13 68
# is_traversable 14 69
# is_traversable 14 69
# is_traversable 14 70
# 12 68 47
# 12 69 19
# 13 68 58
# 14 68 78
# 14 69 41
# Current node 12, 69, interval 19
# is_traversable 11 68
# is_traversable 12 68
# is_traversable 11 69
# is_traversable 11 69
# is_traversable 11 70
# is_traversable 12 68
# is_traversable 12 69
# is_traversable 12 70
# is_traversable 13 68
# is_traversable 12 68
# is_traversable 13 69
# is_traversable 13 69
# is_traversable 13 70
# 11 68 52
# 11 69 32
# 12 68 47
# 13 68 58
# 13 69 40
# Current node 11, 69, interval 32
# is_traversable 10 68
# is_traversable 11 68
# is_traversable 10 69
# is_traversable 10 69
# is_traversable 10 70
# is_traversable 11 70
# is_traversable 10 69
# is_traversable 11 68
# is_traversable 11 69
# is_traversable 11 70
# is_traversable 12 68
# is_traversable 11 68
# is_traversable 12 69
# is_traversable 12 69
# is_traversable 12 70
# 10 68 51
# 10 69 37
# 10 70 44
# 11 68 52
# 12 68 47
# 12 69 19
# Current node 10, 69, interval 37
# is_traversable 9 68
# is_traversable 10 68
# is_traversable 9 69
# is_traversable 9 69
# is_traversable 9 70
# is_traversable 10 70
# is_traversable 9 69
# is_traversable 10 68
# is_traversable 10 69
# is_traversable 10 70
# is_traversable 11 68
# is_traversable 10 68
# is_traversable 11 69
# is_traversable 11 69
# is_traversable 11 70
# 9 68 32
# 9 69 44
# 9 70 38
# 10 68 51
# 10 70 44
# 11 68 52
# 11 69 32
# Current node 9, 69, interval 44
# is_traversable 8 68
# is_traversable 9 68
# is_traversable 8 69
# is_traversable 8 69
# is_traversable 8 70
# is_traversable 9 70
# is_traversable 8 69
# is_traversable 9 68
# is_traversable 9 69
# is_traversable 9 70
# is_traversable 10 68
# is_traversable 9 68
# is_traversable 10 69
# is_traversable 10 69
# is_traversable 10 70
# is_traversable 9 70
# is_traversable 10 69
# 8 68 44
# 8 69 30
# 8 70 39
# 9 68 32
# 9 70 38
# 10 68 51
# 10 69 37
# 10 70 44
# Current node 8, 69, interval 30
# is_traversable 7 68
# is_traversable 8 68
# is_traversable 7 69
# is_traversable 7 69
# is_traversable 7 70
# is_traversable 8 68
# is_traversable 8 69
# is_traversable 8 70
# is_traversable 9 68
# is_traversable 8 68
# is_traversable 9 69
# is_traversable 9 69
# is_traversable 9 70
# is_traversable 8 70
# is_traversable 9 69
# 7 68 52
# 7 69 40
# 8 68 44
# 8 70 39
# 9 68 32
# 9 69 44
# 9 70 38
# Current node 7, 69, interval 40
# is_traversable 6 68
# is_traversable 7 68
# is_traversable 6 69
# is_traversable 6 69
# is_traversable 6 70
# is_traversable 7 68
# is_traversable 7 69
# is_traversable 7 70
# is_traversable 8 68
# is_traversable 7 68
# is_traversable 8 69
# is_traversable 8 69
# is_traversable 8 70
# is_traversable 7 70
# is_traversable 8 69
# 6 68 45
# 6 69 37
# 7 68 52
# 8 68 44
# 8 69 30
# 8 70 39

# %%
lst = [current]
while current.parent is not None:
    lst.append(current.parent)
    current = current.parent

print(len(lst))

for el in list(reversed(lst)):
    print(el.i, el.j)
# Out:
# 70
# 33 9
# 32 10
# 31 11
# 30 12
# 29 13
# 28 14
# 27 15
# 26 16
# 26 17
# 26 18
# 26 19
# 26 20
# 26 21
# 26 22
# 26 23
# 26 24
# 26 25
# 26 26
# 26 27
# 26 28
# 26 29
# 26 30
# 26 31
# 26 32
# 26 33
# 26 34
# 26 35
# 26 36
# 26 37
# 26 38
# 26 39
# 26 40
# 26 41
# 26 42
# 26 43
# 26 44
# 26 45
# 26 46
# 26 47
# 26 48
# 26 49
# 26 50
# 26 51
# 26 52
# 26 53
# 26 54
# 27 55
# 27 56
# 27 57
# 26 58
# 25 59
# 24 60
# 23 61
# 22 62
# 21 63
# 20 64
# 19 65
# 18 66
# 17 67
# 16 68
# 15 69
# 14 69
# 13 69
# 12 69
# 11 69
# 10 69
# 9 69
# 8 69
# 7 69
# 6 69

# %%
print(test_map.map[33][9])
# Out:
# [<__main__.Interval object at 0x136d12310>, <__main__.Interval object at 0x136d42950>, <__main__.Interval object at 0x136d06d50>, <__main__.Interval object at 0x136d10410>, <__main__.Interval object at 0x136d14a10>, <__main__.Interval object at 0x136d07850>, <__main__.Interval object at 0x136d1d250>, <__main__.Interval object at 0x136d1c050>, <__main__.Interval object at 0x136d07990>, <__main__.Interval object at 0x136d13c50>, <__main__.Interval object at 0x136d0e250>, <__main__.Interval object at 0x136d05e50>, <__main__.Interval object at 0x136d06f10>, <__main__.Interval object at 0x136d10950>, <__main__.Interval object at 0x136d0f710>, <__main__.Interval object at 0x136d14490>, <__main__.Interval object at 0x136d0e9d0>, <__main__.Interval object at 0x136d15f50>, <__main__.Interval object at 0x136d06f50>, <__main__.Interval object at 0x136d0e3d0>, <__main__.Interval object at 0x136d13510>, <__main__.Interval object at 0x136d17150>, <__main__.Interval object at 0x136d0fad0>, <__main__.Interval object at 0x136d14fd0>, <__main__.Interval object at 0x136d16510>, <__main__.Interval object at 0x136d058d0>, <__main__.Interval object at 0x136d06c90>, <__main__.Interval object at 0x136d07cd0>, <__main__.Interval object at 0x136d0f6d0>, <__main__.Interval object at 0x136d167d0>, <__main__.Interval object at 0x136d07350>, <__main__.Interval object at 0x136d15b10>, <__main__.Interval object at 0x136d06cd0>, <__main__.Interval object at 0x136d065d0>, <__main__.Interval object at 0x136d0e0d0>, <__main__.Interval object at 0x136d0dfd0>]
